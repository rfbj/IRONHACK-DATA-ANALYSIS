# %%
import pandas as pd
import os

# %% [markdown]
# # API Wrappers

# %% [markdown]
# ## Dealing with `keys` in code
#
# Usually, when you access an API, you'll use some password or `key`.
#
# There's a package called `dotenv` that helps you hide your keys inside a file.

# %% [markdown]
# - Install dotenv `!pip install python-dotenv`
# - Create a file with a `.env` extension and variables inside of it like
# ```
# API_KEY="l1noPOPAixCPM"
# API_SECRET="GraGq0zrGhs1qvbA0xQXsZBKuTkK5MJ"
# ```
# - run dotenv.load_dotenv('filename.env')
# - now if you run os.getenv('API_KEY'), it will contain the string 'l1noPOPAixCPM'
# - the idea is that you can upload your code to Github and **DON'T** upload the `.env` file

# %%
from dotenv import load_dotenv

# %%
# after running the code below, you'll have access to the variables inside this file
load_dotenv('arquivo.env')
# Out:
# True

# %%
import os
#os.getenv('API_KEY')

# %%
# you can safely store it inside a variable and use it inside your API
API_KEY = os.getenv('qualquer_coisa')

# %%
API_KEY

# %%
from password import variable_example
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [18], in <module>
# ----> 1 from password import variable_example
#
# ModuleNotFoundError: No module named 'password'

# %%
variable_example
# Out:
# 123

# %% [markdown]
# ## List of API wrappers
#
# - This is a list of some known python packages that facilitates the use of some APIs:
# https://github.com/realpython/list-of-python-api-wrappers
#
# - But there are much more than that. You just have to look for it. Here's a list of some public APIs grouped by type: https://github.com/public-apis/public-apis. Maybe you can find an API wrapper for those too. You just need to search google something like: `name_of_the_api python wrapper`
#
# - API para o `Portal da Transparência` (Brasil): http://www.transparencia.gov.br/swagger-ui.html
#
# - Here's another list of fun APIs: https://apilist.fun/

# %% [markdown]
# # Use Cases

# %% [markdown]
# ## OMDB:
#
# http://www.omdbapi.com/

# %% [markdown]
# https://github.com/dgilland/omdb.py
#
# Install API wrapper: `!pip install omdb`

# %%
import omdb

# %%
from dotenv import load_dotenv
load_dotenv('keys_api.env')
# Out:
# True

# %%
from omdb import OMDBClient

client = OMDBClient(apikey=os.getenv('OMDB_HOTMAIL_KEY'))

# %%
client.
# Out:
#   File "<ipython-input-12-aa4d2e851f66>", line 1
#     client.
#            ^
# SyntaxError: invalid syntax

# %%
client.search('friends')
# Out:
# [{'title': 'Friends',
#   'year': '1994–2004',
#   'imdb_id': 'tt0108778',
#   'type': 'series',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNDVkYjU0MzctMWRmZi00NTkxLTgwZWEtOWVhYjZlYjllYmU4XkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SX300.jpg'},
#  {'title': 'Friends with Benefits',
#   'year': '2011',
#   'imdb_id': 'tt1632708',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2MzQ0NTk4N15BMl5BanBnXkFtZTcwMDc2NDYzNQ@@._V1_SX300.jpg'},
#  {'title': 'Just Friends',
#   'year': '2005',
#   'imdb_id': 'tt0433400',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjA0Mzg2NjUzMl5BMl5BanBnXkFtZTcwNDg2ODUzMQ@@._V1_SX300.jpg'},
#  {'title': 'How to Lose Friends & Alienate People',
#   'year': '2008',
#   'imdb_id': 'tt0455538',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjY0MzFmMDgtY2ZiOC00M2QyLWFmOWMtOTBmZWY4OWE2YTYzXkEyXkFqcGdeQXVyMjA5MTIzMjQ@._V1_SX300.jpg'},
#  {'title': 'Friends with Kids',
#   'year': '2011',
#   'imdb_id': 'tt1720616',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTcyMDI2NjU2Ml5BMl5BanBnXkFtZTcwNjA4MzQzNw@@._V1_SX300.jpg'},
#  {'title': 'We Are Your Friends',
#   'year': '2015',
#   'imdb_id': 'tt3787590',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjE2NjIxODUxNF5BMl5BanBnXkFtZTgwMjI1MzM1NjE@._V1_SX300.jpg'},
#  {'title': 'Friends with Money',
#   'year': '2006',
#   'imdb_id': 'tt0436331',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjE3Mjc3NjQ5NV5BMl5BanBnXkFtZTYwMjY5MjE3._V1_SX300.jpg'},
#  {'title': "Foster's Home for Imaginary Friends",
#   'year': '2004–2009',
#   'imdb_id': 'tt0419326',
#   'type': 'series',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYmE2ZmMzZjEtOTAyOS00NWNhLTgzOWYtMzFkNmJhYzBiN2VhXkEyXkFqcGdeQXVyMzM4NjcxOTc@._V1_SX300.jpg'},
#  {'title': 'Friends from College',
#   'year': '2017–2019',
#   'imdb_id': 'tt5565334',
#   'type': 'series',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjMyNjgxNDc3MV5BMl5BanBnXkFtZTgwNDUyMzQ2NjM@._V1_SX300.jpg'},
#  {'title': 'Happy Tree Friends',
#   'year': '2000–',
#   'imdb_id': 'tt0770762',
#   'type': 'series',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMzRiMjRkNDYtNjNmZC00MTQwLThjNGQtZDEzZDA0OWVlOWUxXkEyXkFqcGdeQXVyMjAxODI1Nzk@._V1_SX300.jpg'}]

# %%
url = client.get(title='Friends')['poster']

# %%
url
# Out:
# 'https://m.media-amazon.com/images/M/MV5BNDVkYjU0MzctMWRmZi00NTkxLTgwZWEtOWVhYjZlYjllYmU4XkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SX300.jpg'

# %%
import requests
from PIL import Image

response = requests.get(url, stream=True)
Image.open(response.raw)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x441 at 0x18082C28940>

# %%
client.search('Titanic')
# Out:
# [{'title': 'Titanic',
#   'year': '1997',
#   'imdb_id': 'tt0120338',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMDdmZGU3NDQtY2E5My00ZTliLWIzOTUtMTY4ZGI1YjdiNjk3XkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SX300.jpg'},
#  {'title': 'Titanic II',
#   'year': '2010',
#   'imdb_id': 'tt1640571',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTMxMjQ1MjA5Ml5BMl5BanBnXkFtZTcwNjIzNjg1Mw@@._V1_SX300.jpg'},
#  {'title': 'Titanic - La leggenda continua',
#   'year': '2000',
#   'imdb_id': 'tt0330994',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTg5MjcxODAwMV5BMl5BanBnXkFtZTcwMTk4OTMwMg@@._V1_SX300.jpg'},
#  {'title': 'Titanic',
#   'year': '1953',
#   'imdb_id': 'tt0046435',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTU3NTUyMTc3Nl5BMl5BanBnXkFtZTgwOTA2MDE3MTE@._V1_SX300.jpg'},
#  {'title': 'Titanic',
#   'year': '1996',
#   'imdb_id': 'tt0115392',
#   'type': 'series',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTBhMjUzMDItYTBlZS00OThkLWJmZDQtMjg1YTQ5ZDkxYmFjXkEyXkFqcGdeQXVyNjk1Njg5NTA@._V1_SX300.jpg'},
#  {'title': 'Raise the Titanic',
#   'year': '1980',
#   'imdb_id': 'tt0081400',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNTQyZGI0NDgtYTM0ZC00NTdkLTk2OTItYTgwYmYwNjZlNDRlXkEyXkFqcGdeQXVyMTY5Nzc4MDY@._V1_SX300.jpg'},
#  {'title': 'The Legend of the Titanic',
#   'year': '1999',
#   'imdb_id': 'tt1623780',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjMxNDU5MTk1MV5BMl5BanBnXkFtZTgwMDk5NDUyMTE@._V1_SX300.jpg'},
#  {'title': 'Titanic',
#   'year': '2012',
#   'imdb_id': 'tt1869152',
#   'type': 'series',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTA4MjIyZWEtZjYwMS00ZmQ1LWJiMDEtMWNiNTI5NWE3OGJjXkEyXkFqcGdeQXVyNjk1Njg5NTA@._V1_SX300.jpg'},
#  {'title': 'Titanic: Blood and Steel',
#   'year': '2012–',
#   'imdb_id': 'tt1695366',
#   'type': 'series',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjI2MzU2NzEzN15BMl5BanBnXkFtZTcwMzI5NTU3Nw@@._V1_SX300.jpg'},
#  {'title': 'In Search of the Titanic',
#   'year': '2004',
#   'imdb_id': 'tt1719665',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTAzNjY0NDA2NzdeQTJeQWpwZ15BbWU4MDIwMzc1MzEx._V1_SX300.jpg'}]

# %%
url = client.get('Titanic II')[0]['poster']

# %%
url
# Out:
# 'https://m.media-amazon.com/images/M/MV5BMTMxMjQ1MjA5Ml5BMl5BanBnXkFtZTcwNjIzNjg1Mw@@._V1_SX300.jpg'

# %%
response = requests.get(url, stream=True)
Image.open(response.raw)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x422 at 0x180E6133730>

# %% [markdown]
# ## Spotify

# %% [markdown]
# Install spotipy: `pip install spotipy`

# %% [markdown]
# Read its documentation: https://spotipy.readthedocs.io/en/2.14.0/

# %% [markdown]
# If you read the documentation, it tells you to get your `access key` at https://developer.spotify.com/documentation/web-api/. You can view the `quick-start` tab or follow the guidelines here.
#
# - Click on `Dashboard`
# - Log in to your Spotify account
# - Create an APP
# - Collect your `Client ID` and `Client Secret` (click on SHOW CLIENT SECRET)
# - Click on `Edit Settings` on your app's dashboard
#     - You have to insert a `redirect_uri` (I've put: https://www.google.com. You can put anything.)
# - Find your username ID in your profile settings.
#
#
# - Code Samples: https://github.com/plamere/spotipy/tree/master/examples

# %%
client_id = os.getenv('SPOTIPY_CLIENT_ID')
client_secret = os.getenv('SP_CLIENT_SECRET')

# %% [markdown]
# ### Authentication

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id,
                                                           client_secret=client_secret))

# %% [markdown]
# ### Users `current_playing` status

# %%
sp.currently_playing()
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/me/player/currently-playing returned 404 due to Invalid username
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
#     246             results = response.json()
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\requests\models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/me/player/currently-playing
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-24-135aeeccc6d7> in <module>
# ----> 1 sp.currently_playing()
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in currently_playing(self, market, additional_types)
#    1649                 - additional_types - `episode` to get podcast track information
#    1650         """
# -> 1651         return self._get("me/player/currently-playing", market=market,
#    1652                          additional_types=additional_types)
#    1653
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in _get(self, url, args, payload, **kwargs)
#     289             kwargs.update(args)
#     290
# --> 291         return self._internal_call("GET", url, payload, kwargs)
#     292
#     293     def _post(self, url, args=None, payload=None, **kwargs):
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     259                          method, url, response.status_code, msg)
#     260
# --> 261             raise SpotifyException(
#     262                 response.status_code,
#     263                 -1,
#
# SpotifyException: http status: 404, code:-1 - https://api.spotify.com/v1/me/player/currently-playing:
#  Invalid username, reason: None

# %%
sp.currently_playing()['item']['album']['images']

# %% [markdown]
# ### Skip song

# %%
sp.next_track()
# Out:
# HTTP Error for POST to https://api.spotify.com/v1/me/player/next returned 403 due to Player command failed: Premium required
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
#     246             results = response.json()
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\requests\models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.spotify.com/v1/me/player/next
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-25-2f2583c5460b> in <module>
# ----> 1 sp.next_track()
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in next_track(self, device_id)
#    1722                 - device_id - device target for playback
#    1723         """
# -> 1724         return self._post(self._append_device_id("me/player/next", device_id))
#    1725
#    1726     def previous_track(self, device_id=None):
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in _post(self, url, args, payload, **kwargs)
#     294         if args:
#     295             kwargs.update(args)
# --> 296         return self._internal_call("POST", url, payload, kwargs)
#     297
#     298     def _delete(self, url, args=None, payload=None, **kwargs):
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     259                          method, url, response.status_code, msg)
#     260
# --> 261             raise SpotifyException(
#     262                 response.status_code,
#     263                 -1,
#
# SpotifyException: http status: 403, code:-1 - https://api.spotify.com/v1/me/player/next:
#  Player command failed: Premium required, reason: PREMIUM_REQUIRED

# %%
sp.currently_playing()
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/me/player/currently-playing returned 404 due to Invalid username
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
#     246             results = response.json()
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\requests\models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/me/player/currently-playing
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-26-135aeeccc6d7> in <module>
# ----> 1 sp.currently_playing()
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in currently_playing(self, market, additional_types)
#    1649                 - additional_types - `episode` to get podcast track information
#    1650         """
# -> 1651         return self._get("me/player/currently-playing", market=market,
#    1652                          additional_types=additional_types)
#    1653
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in _get(self, url, args, payload, **kwargs)
#     289             kwargs.update(args)
#     290
# --> 291         return self._internal_call("GET", url, payload, kwargs)
#     292
#     293     def _post(self, url, args=None, payload=None, **kwargs):
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     259                          method, url, response.status_code, msg)
#     260
# --> 261             raise SpotifyException(
#     262                 response.status_code,
#     263                 -1,
#
# SpotifyException: http status: 404, code:-1 - https://api.spotify.com/v1/me/player/currently-playing:
#  Invalid username, reason: None

# %%
sp.currently_playing().keys()
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/me/player/currently-playing returned 404 due to Invalid username
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
#     246             results = response.json()
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\requests\models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/me/player/currently-playing
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-27-db154cb5ff7c> in <module>
# ----> 1 sp.currently_playing().keys()
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in currently_playing(self, market, additional_types)
#    1649                 - additional_types - `episode` to get podcast track information
#    1650         """
# -> 1651         return self._get("me/player/currently-playing", market=market,
#    1652                          additional_types=additional_types)
#    1653
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in _get(self, url, args, payload, **kwargs)
#     289             kwargs.update(args)
#     290
# --> 291         return self._internal_call("GET", url, payload, kwargs)
#     292
#     293     def _post(self, url, args=None, payload=None, **kwargs):
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     259                          method, url, response.status_code, msg)
#     260
# --> 261             raise SpotifyException(
#     262                 response.status_code,
#     263                 -1,
#
# SpotifyException: http status: 404, code:-1 - https://api.spotify.com/v1/me/player/currently-playing:
#  Invalid username, reason: None

# %%
sp.currently_playing()['item']['album']['id']
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/me/player/currently-playing returned 404 due to Invalid username
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
#     246             results = response.json()
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\requests\models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/me/player/currently-playing
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-28-eb2e04544032> in <module>
# ----> 1 sp.currently_playing()['item']['album']['id']
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in currently_playing(self, market, additional_types)
#    1649                 - additional_types - `episode` to get podcast track information
#    1650         """
# -> 1651         return self._get("me/player/currently-playing", market=market,
#    1652                          additional_types=additional_types)
#    1653
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in _get(self, url, args, payload, **kwargs)
#     289             kwargs.update(args)
#     290
# --> 291         return self._internal_call("GET", url, payload, kwargs)
#     292
#     293     def _post(self, url, args=None, payload=None, **kwargs):
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     259                          method, url, response.status_code, msg)
#     260
# --> 261             raise SpotifyException(
#     262                 response.status_code,
#     263                 -1,
#
# SpotifyException: http status: 404, code:-1 - https://api.spotify.com/v1/me/player/currently-playing:
#  Invalid username, reason: None

# %%
sp.volume(10)
# Out:
# HTTP Error for PUT to https://api.spotify.com/v1/me/player/volume?volume_percent=10 returned 403 due to Player command failed: Premium required
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
#     246             results = response.json()
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\requests\models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.spotify.com/v1/me/player/volume?volume_percent=10
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-30-0bc13b435865> in <module>
# ----> 1 sp.volume(10)
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in volume(self, volume_percent, device_id)
#    1779             logger.warning("Volume must be between 0 and 100, inclusive")
#    1780             return
# -> 1781         self._put(
#    1782             self._append_device_id(
#    1783                 "me/player/volume?volume_percent=%s" % volume_percent,
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in _put(self, url, args, payload, **kwargs)
#     304         if args:
#     305             kwargs.update(args)
# --> 306         return self._internal_call("PUT", url, payload, kwargs)
#     307
#     308     def next(self, result):
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     259                          method, url, response.status_code, msg)
#     260
# --> 261             raise SpotifyException(
#     262                 response.status_code,
#     263                 -1,
#
# SpotifyException: http status: 403, code:-1 - https://api.spotify.com/v1/me/player/volume?volume_percent=10:
#  Player command failed: Premium required, reason: PREMIUM_REQUIRED

# %% [markdown]
# ### Get playlist tracks

# %%
# playlist
playlist = '0q1VKI0FlEs3o2Ap2nPCs3'

# %%
sp.user_playlist_tracks(username, playlist).keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-bdd692348b4d> in <module>
# ----> 1 sp.user_playlist_tracks(username, playlist).keys()
#
# NameError: name 'username' is not defined

# %%
sp.user_playlist_tracks(username, playlist)['items'][1]['track']['id']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-dd9745779f03> in <module>
# ----> 1 sp.user_playlist_tracks(username, playlist)['items'][1]['track']['id']
#
# NameError: name 'username' is not defined

# %%
sp.add_to_queue('0Em8m9kRctyH9S3MTXAHvY')
sp.next_track()

# %%
sp.pause_playback()

# %% [markdown]
# ### Get Audio Features

# %%
sp.album_tracks('0AqgcUe5Z3x9D9xtyR57qT')
# Out:
# {'href': 'https://api.spotify.com/v1/albums/0AqgcUe5Z3x9D9xtyR57qT/tracks?offset=0&limit=50',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7iJl63aJyNd8C6NZlMv6kp'},
#      'href': 'https://api.spotify.com/v1/artists/7iJl63aJyNd8C6NZlMv6kp',
#      'id': '7iJl63aJyNd8C6NZlMv6kp',
#      'name': 'Tchakabum',
#      'type': 'artist',
#      'uri': 'spotify:artist:7iJl63aJyNd8C6NZlMv6kp'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 275706,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4ebLB7MhWDEq5sxrLwitXy'},
#    'href': 'https://api.spotify.com/v1/tracks/4ebLB7MhWDEq5sxrLwitXy',
#    'id': '4ebLB7MhWDEq5sxrLwitXy',
#    'is_local': False,
#    'name': 'Onda Onda (Olha a Onda)',
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4ebLB7MhWDEq5sxrLwitXy'}],
#  'limit': 50,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 1}

# %%
sp.audio_features('7KBfjlQ85Fqs2MCCvXSW0c')
# Out:
# [{'danceability': 0.957,
#   'energy': 0.667,
#   'key': 10,
#   'loudness': -5.353,
#   'mode': 0,
#   'speechiness': 0.0856,
#   'acousticness': 0.826,
#   'instrumentalness': 0.0205,
#   'liveness': 0.179,
#   'valence': 0.556,
#   'tempo': 132.01,
#   'type': 'audio_features',
#   'id': '7KBfjlQ85Fqs2MCCvXSW0c',
#   'uri': 'spotify:track:7KBfjlQ85Fqs2MCCvXSW0c',
#   'track_href': 'https://api.spotify.com/v1/tracks/7KBfjlQ85Fqs2MCCvXSW0c',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7KBfjlQ85Fqs2MCCvXSW0c',
#   'duration_ms': 155550,
#   'time_signature': 4}]

# %%
sp.audio_features('37Tmv4NnfQeb0ZgUC4fOJj')
# Out:
# [{'danceability': 0.733,
#   'energy': 0.794,
#   'key': 5,
#   'loudness': -10.023,
#   'mode': 1,
#   'speechiness': 0.0307,
#   'acousticness': 0.0614,
#   'instrumentalness': 0.0367,
#   'liveness': 0.33,
#   'valence': 0.931,
#   'tempo': 148.174,
#   'type': 'audio_features',
#   'id': '37Tmv4NnfQeb0ZgUC4fOJj',
#   'uri': 'spotify:track:37Tmv4NnfQeb0ZgUC4fOJj',
#   'track_href': 'https://api.spotify.com/v1/tracks/37Tmv4NnfQeb0ZgUC4fOJj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/37Tmv4NnfQeb0ZgUC4fOJj',
#   'duration_ms': 348624,
#   'time_signature': 4}]

# %%
sp.audio_features(['37Tmv4NnfQeb0ZgUC4fOJj','6kxwc5gVuazlFo178WoVbF'])
# Out:
# [{'danceability': 0.733,
#   'energy': 0.794,
#   'key': 5,
#   'loudness': -10.023,
#   'mode': 1,
#   'speechiness': 0.0307,
#   'acousticness': 0.0614,
#   'instrumentalness': 0.0367,
#   'liveness': 0.33,
#   'valence': 0.931,
#   'tempo': 148.174,
#   'type': 'audio_features',
#   'id': '37Tmv4NnfQeb0ZgUC4fOJj',
#   'uri': 'spotify:track:37Tmv4NnfQeb0ZgUC4fOJj',
#   'track_href': 'https://api.spotify.com/v1/tracks/37Tmv4NnfQeb0ZgUC4fOJj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/37Tmv4NnfQeb0ZgUC4fOJj',
#   'duration_ms': 348624,
#   'time_signature': 4},
#  {'danceability': 0.481,
#   'energy': 0.807,
#   'key': 4,
#   'loudness': -10.447,
#   'mode': 1,
#   'speechiness': 0.0468,
#   'acousticness': 0.0316,
#   'instrumentalness': 1.28e-06,
#   'liveness': 0.395,
#   'valence': 0.463,
#   'tempo': 153.821,
#   'type': 'audio_features',
#   'id': '6kxwc5gVuazlFo178WoVbF',
#   'uri': 'spotify:track:6kxwc5gVuazlFo178WoVbF',
#   'track_href': 'https://api.spotify.com/v1/tracks/6kxwc5gVuazlFo178WoVbF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6kxwc5gVuazlFo178WoVbF',
#   'duration_ms': 291387,
#   'time_signature': 4}]

# %%
pd.DataFrame(sp.audio_features(['1pBWfNZ0HQBFbDsFQHtb39','4ebLB7MhWDEq5sxrLwitXy', '198vEZJYqlOtiWw2e1mPmq',
                                     '37Tmv4NnfQeb0ZgUC4fOJj','6kxwc5gVuazlFo178WoVbF']))
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.576   0.887    2    -7.382     1       0.1230        0.2310
# 1         0.666   0.805    1    -7.396     0       0.2190        0.3620
# 2         0.662   0.900    4    -4.300     1       0.1070        0.5080
# 3         0.733   0.794    5   -10.023     1       0.0307        0.0614
# 4         0.481   0.807    4   -10.447     1       0.0468        0.0316
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.110000    0.9510    0.607   98.817  audio_features
# 1          0.000126    0.0716    0.437   92.631  audio_features
# 2          0.000889    0.3450    0.840  135.868  audio_features
# 3          0.036700    0.3300    0.931  148.174  audio_features
# 4          0.000001    0.3950    0.463  153.821  audio_features
#
#                        id                                   uri  \
# 0  1pBWfNZ0HQBFbDsFQHtb39  spotify:track:1pBWfNZ0HQBFbDsFQHtb39
# 1  4ebLB7MhWDEq5sxrLwitXy  spotify:track:4ebLB7MhWDEq5sxrLwitXy
# 2  198vEZJYqlOtiWw2e1mPmq  spotify:track:198vEZJYqlOtiWw2e1mPmq
# 3  37Tmv4NnfQeb0ZgUC4fOJj  spotify:track:37Tmv4NnfQeb0ZgUC4fOJj
# 4  6kxwc5gVuazlFo178WoVbF  spotify:track:6kxwc5gVuazlFo178WoVbF
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1pBWfNZ0HQBF...
# 1  https://api.spotify.com/v1/tracks/4ebLB7MhWDEq...
# 2  https://api.spotify.com/v1/tracks/198vEZJYqlOt...
# 3  https://api.spotify.com/v1/tracks/37Tmv4NnfQeb...
# 4  https://api.spotify.com/v1/tracks/6kxwc5gVuazl...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1pBW...       230920
# 1  https://api.spotify.com/v1/audio-analysis/4ebL...       275707
# 2  https://api.spotify.com/v1/audio-analysis/198v...       182693
# 3  https://api.spotify.com/v1/audio-analysis/37Tm...       348624
# 4  https://api.spotify.com/v1/audio-analysis/6kxw...       291387
#
#    time_signature
# 0               4
# 1               4
# 2               3
# 3               4
# 4               4

# %% [markdown]
# ### Get top tracks given artist URI

# %%
sp.artist_top_tracks('3Qyjq5eQNKo5tHVmXyhvtB')['tracks']
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#      'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#      'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#      'name': 'Netinho',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0Igyv5Qr7kCTrTXHpYlalY'},
#    'href': 'https://api.spotify.com/v1/albums/0Igyv5Qr7kCTrTXHpYlalY',
#    'id': '0Igyv5Qr7kCTrTXHpYlalY',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f0eb2cf2e85866fc180fbe40',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f0eb2cf2e85866fc180fbe40',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f0eb2cf2e85866fc180fbe40',
#      'width': 64}],
#    'name': 'Total - O Melhor De Netinho',
#    'release_date': '1997-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:0Igyv5Qr7kCTrTXHpYlalY'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#     'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#     'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#     'name': 'Netinho',
#     'type': 'artist',
#     'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#   'disc_number': 1,
#   'duration_ms': 291386,
#   'explicit': False,
#   'external_ids': {'isrc': 'BRUM70600120'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5jo0WixbdL2ZS8qSx45qa4'},
#   'href': 'https://api.spotify.com/v1/tracks/5jo0WixbdL2ZS8qSx45qa4',
#   'id': '5jo0WixbdL2ZS8qSx45qa4',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Milla - Ao Vivo',
#   'popularity': 29,
#   'preview_url': None,
#   'track_number': 8,
#   'type': 'track',
#   'uri': 'spotify:track:5jo0WixbdL2ZS8qSx45qa4'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#      'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#      'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#      'name': 'Netinho',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0Igyv5Qr7kCTrTXHpYlalY'},
#    'href': 'https://api.spotify.com/v1/albums/0Igyv5Qr7kCTrTXHpYlalY',
#    'id': '0Igyv5Qr7kCTrTXHpYlalY',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f0eb2cf2e85866fc180fbe40',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f0eb2cf2e85866fc180fbe40',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f0eb2cf2e85866fc180fbe40',
#      'width': 64}],
#    'name': 'Total - O Melhor De Netinho',
#    'release_date': '1997-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:0Igyv5Qr7kCTrTXHpYlalY'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#     'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#     'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#     'name': 'Netinho',
#     'type': 'artist',
#     'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#   'disc_number': 1,
#   'duration_ms': 217480,
#   'explicit': False,
#   'external_ids': {'isrc': 'BRPGD9300066'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/10KqqxNjUVwT38QJkCwyHg'},
#   'href': 'https://api.spotify.com/v1/tracks/10KqqxNjUVwT38QJkCwyHg',
#   'id': '10KqqxNjUVwT38QJkCwyHg',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Menina',
#   'popularity': 17,
#   'preview_url': None,
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:10KqqxNjUVwT38QJkCwyHg'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#      'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#      'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#      'name': 'Netinho',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0Igyv5Qr7kCTrTXHpYlalY'},
#    'href': 'https://api.spotify.com/v1/albums/0Igyv5Qr7kCTrTXHpYlalY',
#    'id': '0Igyv5Qr7kCTrTXHpYlalY',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f0eb2cf2e85866fc180fbe40',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f0eb2cf2e85866fc180fbe40',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f0eb2cf2e85866fc180fbe40',
#      'width': 64}],
#    'name': 'Total - O Melhor De Netinho',
#    'release_date': '1997-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:0Igyv5Qr7kCTrTXHpYlalY'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#     'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#     'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#     'name': 'Netinho',
#     'type': 'artist',
#     'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#   'disc_number': 1,
#   'duration_ms': 201653,
#   'explicit': False,
#   'external_ids': {'isrc': 'BRPGD9700579'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6mx99rlPKCxJlAvhlTx0mt'},
#   'href': 'https://api.spotify.com/v1/tracks/6mx99rlPKCxJlAvhlTx0mt',
#   'id': '6mx99rlPKCxJlAvhlTx0mt',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Fim De Semana',
#   'popularity': 41,
#   'preview_url': None,
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:6mx99rlPKCxJlAvhlTx0mt'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#      'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#      'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#      'name': 'Netinho',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/79ifKBzMdeSXZe2Wizmf58'},
#    'href': 'https://api.spotify.com/v1/albums/79ifKBzMdeSXZe2Wizmf58',
#    'id': '79ifKBzMdeSXZe2Wizmf58',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738a79038f53988314708b06d1',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028a79038f53988314708b06d1',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518a79038f53988314708b06d1',
#      'width': 64}],
#    'name': 'Netinho',
#    'release_date': '1995-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:79ifKBzMdeSXZe2Wizmf58'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#     'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#     'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#     'name': 'Netinho',
#     'type': 'artist',
#     'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#   'disc_number': 1,
#   'duration_ms': 306000,
#   'explicit': False,
#   'external_ids': {'isrc': 'BRPGD9500722'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3qVL0prPqlOAoXrP8ezENu'},
#   'href': 'https://api.spotify.com/v1/tracks/3qVL0prPqlOAoXrP8ezENu',
#   'id': '3qVL0prPqlOAoXrP8ezENu',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Preciso De Você',
#   'popularity': 38,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:3qVL0prPqlOAoXrP8ezENu'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#      'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#      'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#      'name': 'Netinho',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0Igyv5Qr7kCTrTXHpYlalY'},
#    'href': 'https://api.spotify.com/v1/albums/0Igyv5Qr7kCTrTXHpYlalY',
#    'id': '0Igyv5Qr7kCTrTXHpYlalY',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f0eb2cf2e85866fc180fbe40',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f0eb2cf2e85866fc180fbe40',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f0eb2cf2e85866fc180fbe40',
#      'width': 64}],
#    'name': 'Total - O Melhor De Netinho',
#    'release_date': '1997-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:0Igyv5Qr7kCTrTXHpYlalY'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#     'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#     'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#     'name': 'Netinho',
#     'type': 'artist',
#     'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#   'disc_number': 1,
#   'duration_ms': 220880,
#   'explicit': False,
#   'external_ids': {'isrc': 'BRPGD9600586'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/47QcUKtqLAEfnAbvAvWQ8S'},
#   'href': 'https://api.spotify.com/v1/tracks/47QcUKtqLAEfnAbvAvWQ8S',
#   'id': '47QcUKtqLAEfnAbvAvWQ8S',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Beijo Na Boca - Ao Vivo',
#   'popularity': 15,
#   'preview_url': None,
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:47QcUKtqLAEfnAbvAvWQ8S'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#      'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#      'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#      'name': 'Netinho',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0Igyv5Qr7kCTrTXHpYlalY'},
#    'href': 'https://api.spotify.com/v1/albums/0Igyv5Qr7kCTrTXHpYlalY',
#    'id': '0Igyv5Qr7kCTrTXHpYlalY',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f0eb2cf2e85866fc180fbe40',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f0eb2cf2e85866fc180fbe40',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f0eb2cf2e85866fc180fbe40',
#      'width': 64}],
#    'name': 'Total - O Melhor De Netinho',
#    'release_date': '1997-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:0Igyv5Qr7kCTrTXHpYlalY'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#     'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#     'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#     'name': 'Netinho',
#     'type': 'artist',
#     'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#   'disc_number': 1,
#   'duration_ms': 264320,
#   'explicit': False,
#   'external_ids': {'isrc': 'BRMCA9699987'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1gCijwwPAiPMoqS9l7qraO'},
#   'href': 'https://api.spotify.com/v1/tracks/1gCijwwPAiPMoqS9l7qraO',
#   'id': '1gCijwwPAiPMoqS9l7qraO',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Total (Total)',
#   'popularity': 15,
#   'preview_url': None,
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:1gCijwwPAiPMoqS9l7qraO'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#      'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#      'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#      'name': 'Netinho',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3eYnjKxtno6gRlpeEjBGbX'},
#    'href': 'https://api.spotify.com/v1/albums/3eYnjKxtno6gRlpeEjBGbX',
#    'id': '3eYnjKxtno6gRlpeEjBGbX',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c44394f2404f396ef5d0a163',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c44394f2404f396ef5d0a163',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c44394f2404f396ef5d0a163',
#      'width': 64}],
#    'name': 'Axé Bahia',
#    'release_date': '2005-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:3eYnjKxtno6gRlpeEjBGbX'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#     'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#     'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#     'name': 'Netinho',
#     'type': 'artist',
#     'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#   'disc_number': 1,
#   'duration_ms': 367946,
#   'explicit': False,
#   'external_ids': {'isrc': 'BRPGD9600587'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6r58z14RRYF4sO7lSc5nV7'},
#   'href': 'https://api.spotify.com/v1/tracks/6r58z14RRYF4sO7lSc5nV7',
#   'id': '6r58z14RRYF4sO7lSc5nV7',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Prefixo De Verão / We Are The World Of Carnaval / Um Frevo Novo - Ao Vivo',
#   'popularity': 19,
#   'preview_url': None,
#   'track_number': 14,
#   'type': 'track',
#   'uri': 'spotify:track:6r58z14RRYF4sO7lSc5nV7'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#      'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#      'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#      'name': 'Netinho',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1nw1SnK5al4Urljg2CGRMq'},
#    'href': 'https://api.spotify.com/v1/albums/1nw1SnK5al4Urljg2CGRMq',
#    'id': '1nw1SnK5al4Urljg2CGRMq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c6f551840c4a0a97e72ddb5c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c6f551840c4a0a97e72ddb5c',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c6f551840c4a0a97e72ddb5c',
#      'width': 64}],
#    'name': '20 Grandes Sucessos De Netinho',
#    'release_date': '1998-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 20,
#    'type': 'album',
#    'uri': 'spotify:album:1nw1SnK5al4Urljg2CGRMq'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#     'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#     'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#     'name': 'Netinho',
#     'type': 'artist',
#     'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#   'disc_number': 1,
#   'duration_ms': 242533,
#   'explicit': False,
#   'external_ids': {'isrc': 'BRPGD9700583'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6LVsMBPZc6OvNO9M8YN6cC'},
#   'href': 'https://api.spotify.com/v1/tracks/6LVsMBPZc6OvNO9M8YN6cC',
#   'id': '6LVsMBPZc6OvNO9M8YN6cC',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Pra Te Ter Aqui',
#   'popularity': 11,
#   'preview_url': None,
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:6LVsMBPZc6OvNO9M8YN6cC'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#      'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#      'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#      'name': 'Netinho',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0Igyv5Qr7kCTrTXHpYlalY'},
#    'href': 'https://api.spotify.com/v1/albums/0Igyv5Qr7kCTrTXHpYlalY',
#    'id': '0Igyv5Qr7kCTrTXHpYlalY',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f0eb2cf2e85866fc180fbe40',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f0eb2cf2e85866fc180fbe40',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f0eb2cf2e85866fc180fbe40',
#      'width': 64}],
#    'name': 'Total - O Melhor De Netinho',
#    'release_date': '1997-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:0Igyv5Qr7kCTrTXHpYlalY'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#     'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#     'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#     'name': 'Netinho',
#     'type': 'artist',
#     'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#   'disc_number': 1,
#   'duration_ms': 243466,
#   'explicit': False,
#   'external_ids': {'isrc': 'BRPGD9300034'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1Nqcub30TxuHiA3x3xAgyM'},
#   'href': 'https://api.spotify.com/v1/tracks/1Nqcub30TxuHiA3x3xAgyM',
#   'id': '1Nqcub30TxuHiA3x3xAgyM',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Capricho Dos Deuses',
#   'popularity': 25,
#   'preview_url': None,
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:1Nqcub30TxuHiA3x3xAgyM'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#      'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#      'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#      'name': 'Netinho',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1nw1SnK5al4Urljg2CGRMq'},
#    'href': 'https://api.spotify.com/v1/albums/1nw1SnK5al4Urljg2CGRMq',
#    'id': '1nw1SnK5al4Urljg2CGRMq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c6f551840c4a0a97e72ddb5c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c6f551840c4a0a97e72ddb5c',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c6f551840c4a0a97e72ddb5c',
#      'width': 64}],
#    'name': '20 Grandes Sucessos De Netinho',
#    'release_date': '1998-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 20,
#    'type': 'album',
#    'uri': 'spotify:album:1nw1SnK5al4Urljg2CGRMq'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#     'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#     'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#     'name': 'Netinho',
#     'type': 'artist',
#     'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#   'disc_number': 1,
#   'duration_ms': 234293,
#   'explicit': False,
#   'external_ids': {'isrc': 'BRPGD9600585'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/17MgixrvNL7brUlal0WbRl'},
#   'href': 'https://api.spotify.com/v1/tracks/17MgixrvNL7brUlal0WbRl',
#   'id': '17MgixrvNL7brUlal0WbRl',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Estrela Primeira (Amor, Eu Fico) - Ao Vivo',
#   'popularity': 7,
#   'preview_url': None,
#   'track_number': 13,
#   'type': 'track',
#   'uri': 'spotify:track:17MgixrvNL7brUlal0WbRl'}]

# %%
sp.artist_related_artists('3Qyjq5eQNKo5tHVmXyhvtB')
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6NqIUh0cpaygBWUUAjBaog'},
#    'followers': {'href': None, 'total': 180982},
#    'genres': ['axe', 'pagode', 'samba reggae', 'sertanejo'],
#    'href': 'https://api.spotify.com/v1/artists/6NqIUh0cpaygBWUUAjBaog',
#    'id': '6NqIUh0cpaygBWUUAjBaog',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/16d2676fda7cf08b3330daf34b4c9a6f1785d751',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/f444cf7c12b69b76789e0f5b6fc8c6f0c4933dfe',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/17c46b40f109c8154494920a7df12b8eebecb127',
#      'width': 160}],
#    'name': 'Ara Ketu',
#    'popularity': 54,
#    'type': 'artist',
#    'uri': 'spotify:artist:6NqIUh0cpaygBWUUAjBaog'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6scgR2PrQGb4TU4MTCQdVK'},
#    'followers': {'href': None, 'total': 53628},
#    'genres': ['axe', 'pagode', 'samba reggae'],
#    'href': 'https://api.spotify.com/v1/artists/6scgR2PrQGb4TU4MTCQdVK',
#    'id': '6scgR2PrQGb4TU4MTCQdVK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27348b5702fb360fbd68d7d9806',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0248b5702fb360fbd68d7d9806',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485148b5702fb360fbd68d7d9806',
#      'width': 64}],
#    'name': 'Banda Beijo',
#    'popularity': 39,
#    'type': 'artist',
#    'uri': 'spotify:artist:6scgR2PrQGb4TU4MTCQdVK'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/528EuwdQfm7PgHajI0SxcJ'},
#    'followers': {'href': None, 'total': 159274},
#    'genres': ['axe', 'pagode'],
#    'href': 'https://api.spotify.com/v1/artists/528EuwdQfm7PgHajI0SxcJ',
#    'id': '528EuwdQfm7PgHajI0SxcJ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2733b4fbe52e22ee70a2dff359e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e023b4fbe52e22ee70a2dff359e',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048513b4fbe52e22ee70a2dff359e',
#      'width': 64}],
#    'name': 'Asa De Águia',
#    'popularity': 49,
#    'type': 'artist',
#    'uri': 'spotify:artist:528EuwdQfm7PgHajI0SxcJ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1bhqpMFFgoa0NTz82BprgL'},
#    'followers': {'href': None, 'total': 262083},
#    'genres': ['axe', 'pagode'],
#    'href': 'https://api.spotify.com/v1/artists/1bhqpMFFgoa0NTz82BprgL',
#    'id': '1bhqpMFFgoa0NTz82BprgL',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/90c47cfd35e73db7dd43db4e7c7eff7c8466f58c',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ee039de106a6371d74b9ec80206a716b96e7c699',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/a78261fbfef208cbdc3debaee11d42af9fd72f96',
#      'width': 160}],
#    'name': 'Chiclete Com Banana',
#    'popularity': 57,
#    'type': 'artist',
#    'uri': 'spotify:artist:1bhqpMFFgoa0NTz82BprgL'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6cUxFmglW7PeSS5dKaWOtP'},
#    'followers': {'href': None, 'total': 120033},
#    'genres': ['axe', 'pagode', 'samba reggae'],
#    'href': 'https://api.spotify.com/v1/artists/6cUxFmglW7PeSS5dKaWOtP',
#    'id': '6cUxFmglW7PeSS5dKaWOtP',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/888d942ff74f002cd17f59f1c34dc288f1dba69d',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/661e463c4ba8239d9b9bbd0de11b5efe1df8e360',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/a2e6416ac77ba4b859b365cbf8eb7346c3372f11',
#      'width': 160}],
#    'name': 'Terra Samba',
#    'popularity': 49,
#    'type': 'artist',
#    'uri': 'spotify:artist:6cUxFmglW7PeSS5dKaWOtP'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1wqkMc837HWUwdC8sOZ7lZ'},
#    'followers': {'href': None, 'total': 266055},
#    'genres': ['axe', 'mpb', 'pagode', 'samba reggae'],
#    'href': 'https://api.spotify.com/v1/artists/1wqkMc837HWUwdC8sOZ7lZ',
#    'id': '1wqkMc837HWUwdC8sOZ7lZ',
#    'images': [{'height': 1000,
#      'url': 'https://i.scdn.co/image/4b46f6d38f93f12bdc928aa41ca94effe1e13ede',
#      'width': 1000},
#     {'height': 640,
#      'url': 'https://i.scdn.co/image/824521683ec7cd022192057d773183f4e4b36e04',
#      'width': 640},
#     {'height': 200,
#      'url': 'https://i.scdn.co/image/4b3933bce7a834fe6a413e465885be06c4ead576',
#      'width': 200},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/10d27a25813e46e6ac71f4d60a4f67332519f680',
#      'width': 64}],
#    'name': 'Banda Eva',
#    'popularity': 60,
#    'type': 'artist',
#    'uri': 'spotify:artist:1wqkMc837HWUwdC8sOZ7lZ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2jGuS7w8SfDzRNbxW1Lo2c'},
#    'followers': {'href': None, 'total': 158385},
#    'genres': ['axe', 'pagode'],
#    'href': 'https://api.spotify.com/v1/artists/2jGuS7w8SfDzRNbxW1Lo2c',
#    'id': '2jGuS7w8SfDzRNbxW1Lo2c',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/2115bbe11eba09397be74272859fb35bd75be264',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/18e26d810a53969d8623bbfe440b9af1d8523681',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/0e3d4a60567efa8b261b62fbbc775ad8dd99425b',
#      'width': 160}],
#    'name': 'Babado Novo',
#    'popularity': 48,
#    'type': 'artist',
#    'uri': 'spotify:artist:2jGuS7w8SfDzRNbxW1Lo2c'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Da4NyNC4CLayaNGGmL9uZ'},
#    'followers': {'href': None, 'total': 153331},
#    'genres': ['axe', 'pagode', 'samba', 'samba reggae'],
#    'href': 'https://api.spotify.com/v1/artists/1Da4NyNC4CLayaNGGmL9uZ',
#    'id': '1Da4NyNC4CLayaNGGmL9uZ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/5eb6f8b3c9dae18e8959a449f5ea2047476959df',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/189e89a18f1fb7c288173c4547a1a20d047964c8',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/2c615a5e77c7cf9df752ff82093440eb7ccec24d',
#      'width': 160}],
#    'name': 'Timbalada',
#    'popularity': 51,
#    'type': 'artist',
#    'uri': 'spotify:artist:1Da4NyNC4CLayaNGGmL9uZ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0g7wWPHTaQ1L4RwuxLPC3l'},
#    'followers': {'href': None, 'total': 23017},
#    'genres': ['axe'],
#    'href': 'https://api.spotify.com/v1/artists/0g7wWPHTaQ1L4RwuxLPC3l',
#    'id': '0g7wWPHTaQ1L4RwuxLPC3l',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27398565c05da1e3ebf775b4048',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0298565c05da1e3ebf775b4048',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485198565c05da1e3ebf775b4048',
#      'width': 64}],
#    'name': 'Ricardo Chaves',
#    'popularity': 32,
#    'type': 'artist',
#    'uri': 'spotify:artist:0g7wWPHTaQ1L4RwuxLPC3l'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/78oxdhJ0pr4Dkyk0paWUAf'},
#    'followers': {'href': None, 'total': 220149},
#    'genres': ['axe', 'funk carioca', 'pagode'],
#    'href': 'https://api.spotify.com/v1/artists/78oxdhJ0pr4Dkyk0paWUAf',
#    'id': '78oxdhJ0pr4Dkyk0paWUAf',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730355514bc5f60fd3c89173b1',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020355514bc5f60fd3c89173b1',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510355514bc5f60fd3c89173b1',
#      'width': 64}],
#    'name': 'É O Tchan',
#    'popularity': 55,
#    'type': 'artist',
#    'uri': 'spotify:artist:78oxdhJ0pr4Dkyk0paWUAf'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2elJHGuwL43ahofvuD6KGs'},
#    'followers': {'href': None, 'total': 138944},
#    'genres': ['axe', 'pagode'],
#    'href': 'https://api.spotify.com/v1/artists/2elJHGuwL43ahofvuD6KGs',
#    'id': '2elJHGuwL43ahofvuD6KGs',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/2fb581398cd7bee715da2f7bd657230cfbe7f6fa',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/aaa86140c691e1057105543a6932f641e87230c4',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/083e7acaea08b07c2668ff83ab11f16099ade681',
#      'width': 160}],
#    'name': 'Cheiro de Amor',
#    'popularity': 48,
#    'type': 'artist',
#    'uri': 'spotify:artist:2elJHGuwL43ahofvuD6KGs'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7dzq55YG3wjViqexDwiycQ'},
#    'followers': {'href': None, 'total': 1584969},
#    'genres': ['axe',
#     'funk carioca',
#     'mpb',
#     'pagode',
#     'pop nacional',
#     'samba reggae'],
#    'href': 'https://api.spotify.com/v1/artists/7dzq55YG3wjViqexDwiycQ',
#    'id': '7dzq55YG3wjViqexDwiycQ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/54c8deba3655468166ae2bd07ff4c000dd796ffc',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/39385f40818c1cfd29911f6a77a2103c504055aa',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/0d38463e8e99b7ad992f4e7bd4a5b6cc74caf84f',
#      'width': 160}],
#    'name': 'Ivete Sangalo',
#    'popularity': 70,
#    'type': 'artist',
#    'uri': 'spotify:artist:7dzq55YG3wjViqexDwiycQ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4fLuPn1SvWJVFmooqIkvWh'},
#    'followers': {'href': None, 'total': 62876},
#    'genres': ['axe'],
#    'href': 'https://api.spotify.com/v1/artists/4fLuPn1SvWJVFmooqIkvWh',
#    'id': '4fLuPn1SvWJVFmooqIkvWh',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/6925027773fe6bc78fb99f03ba4e4d2ddadb1528',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/26eb14765ee245070130cb758c9f317ffb256293',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/b00ad9b29b1690eacaff4b5afd97a09187b8957c',
#      'width': 160}],
#    'name': 'Luiz Caldas',
#    'popularity': 43,
#    'type': 'artist',
#    'uri': 'spotify:artist:4fLuPn1SvWJVFmooqIkvWh'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3o1Lr9yRGJJhhLlVQFObfC'},
#    'followers': {'href': None, 'total': 409597},
#    'genres': ['axe', 'funk carioca', 'pagode', 'pagode baiano'],
#    'href': 'https://api.spotify.com/v1/artists/3o1Lr9yRGJJhhLlVQFObfC',
#    'id': '3o1Lr9yRGJJhhLlVQFObfC',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/c2f70995b5ff8a47a0e7ac94c1201a7261c8ce88',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/51b3204ca60874f41f07b340448719f89ed5fbee',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/9eb623fce805a2f50da22692c16ec5a1867fb696',
#      'width': 160}],
#    'name': 'Harmonia Do Samba',
#    'popularity': 60,
#    'type': 'artist',
#    'uri': 'spotify:artist:3o1Lr9yRGJJhhLlVQFObfC'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/56vPSwWYuGLNrfy1wlkGB3'},
#    'followers': {'href': None, 'total': 25713},
#    'genres': ['axe', 'pagode', 'sertanejo', 'sertanejo universitario'],
#    'href': 'https://api.spotify.com/v1/artists/56vPSwWYuGLNrfy1wlkGB3',
#    'id': '56vPSwWYuGLNrfy1wlkGB3',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273daf01b57ff028b03cb69d5d3',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02daf01b57ff028b03cb69d5d3',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851daf01b57ff028b03cb69d5d3',
#      'width': 64}],
#    'name': 'Rapazolla',
#    'popularity': 30,
#    'type': 'artist',
#    'uri': 'spotify:artist:56vPSwWYuGLNrfy1wlkGB3'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2u7kjqj92WlpCSAKiOeZ6I'},
#    'followers': {'href': None, 'total': 27836},
#    'genres': ['axe'],
#    'href': 'https://api.spotify.com/v1/artists/2u7kjqj92WlpCSAKiOeZ6I',
#    'id': '2u7kjqj92WlpCSAKiOeZ6I',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734d875b0a59a48f37721f308f',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024d875b0a59a48f37721f308f',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514d875b0a59a48f37721f308f',
#      'width': 64}],
#    'name': 'Banda Mel',
#    'popularity': 35,
#    'type': 'artist',
#    'uri': 'spotify:artist:2u7kjqj92WlpCSAKiOeZ6I'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2krrkKvM52JgvfGu2Uewbg'},
#    'followers': {'href': None, 'total': 207484},
#    'genres': ['axe', 'mpb', 'pagode', 'pagode baiano', 'samba reggae'],
#    'href': 'https://api.spotify.com/v1/artists/2krrkKvM52JgvfGu2Uewbg',
#    'id': '2krrkKvM52JgvfGu2Uewbg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/922c111c5ea773a7b842b6457ce5e0e9ca7dfad4',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/55f06f20c9c1730d7cdefdb40a5571ecf06494a9',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/fd14fbf838a5ece0c0fa81ecdd1599e11f9582fc',
#      'width': 160}],
#    'name': 'Daniela Mercury',
#    'popularity': 55,
#    'type': 'artist',
#    'uri': 'spotify:artist:2krrkKvM52JgvfGu2Uewbg'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0drNUQoEie9lmZKhCdIE6n'},
#    'followers': {'href': None, 'total': 155552},
#    'genres': ['axe', 'pagode'],
#    'href': 'https://api.spotify.com/v1/artists/0drNUQoEie9lmZKhCdIE6n',
#    'id': '0drNUQoEie9lmZKhCdIE6n',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/fff0811b2d39d82dde37b038d139ac36d57c5ce9',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/fe12d38c1bf2941d6a3a63237def8cf877bc3372',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/54ba1e6ca853bc363712db66923b7c93cc293425',
#      'width': 160}],
#    'name': 'Jammil',
#    'popularity': 48,
#    'type': 'artist',
#    'uri': 'spotify:artist:0drNUQoEie9lmZKhCdIE6n'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3tJ9PkBOrG7hFkHeNM2tbw'},
#    'followers': {'href': None, 'total': 134894},
#    'genres': ['axe',
#     'brazilian percussion',
#     'mpb',
#     'pagode',
#     'samba',
#     'samba reggae'],
#    'href': 'https://api.spotify.com/v1/artists/3tJ9PkBOrG7hFkHeNM2tbw',
#    'id': '3tJ9PkBOrG7hFkHeNM2tbw',
#    'images': [{'height': 563,
#      'url': 'https://i.scdn.co/image/c3ef77c1c27ec33d3356ca7665b09aaf2bfe1c23',
#      'width': 1000},
#     {'height': 360,
#      'url': 'https://i.scdn.co/image/50a3a283b53d1cc1a6fa804998d9794d37f52341',
#      'width': 640},
#     {'height': 113,
#      'url': 'https://i.scdn.co/image/17dce4aa9ee548581fec425d814216db62544ce5',
#      'width': 200},
#     {'height': 36,
#      'url': 'https://i.scdn.co/image/4d5f2ecdeff80ab5f6ed2e639682f0c848500854',
#      'width': 64}],
#    'name': 'Olodum',
#    'popularity': 53,
#    'type': 'artist',
#    'uri': 'spotify:artist:3tJ9PkBOrG7hFkHeNM2tbw'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3pliEYuTjFFUfecvfxywbW'},
#    'followers': {'href': None, 'total': 6573},
#    'genres': ['axe'],
#    'href': 'https://api.spotify.com/v1/artists/3pliEYuTjFFUfecvfxywbW',
#    'id': '3pliEYuTjFFUfecvfxywbW',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273cbc85822374138dc992020af',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02cbc85822374138dc992020af',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851cbc85822374138dc992020af',
#      'width': 64}],
#    'name': 'Bamdamel',
#    'popularity': 35,
#    'type': 'artist',
#    'uri': 'spotify:artist:3pliEYuTjFFUfecvfxywbW'}]}

# %%
sp.search('onda onda')
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=onda+onda&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7iJl63aJyNd8C6NZlMv6kp'},
#        'href': 'https://api.spotify.com/v1/artists/7iJl63aJyNd8C6NZlMv6kp',
#        'id': '7iJl63aJyNd8C6NZlMv6kp',
#        'name': 'Tchakabum',
#        'type': 'artist',
#        'uri': 'spotify:artist:7iJl63aJyNd8C6NZlMv6kp'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0CZ4TsU38i1sLvxZ6osPdg'},
#      'href': 'https://api.spotify.com/v1/albums/0CZ4TsU38i1sLvxZ6osPdg',
#      'id': '0CZ4TsU38i1sLvxZ6osPdg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f49fff0c28b37df98185d61e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f49fff0c28b37df98185d61e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f49fff0c28b37df98185d61e',
#        'width': 64}],
#      'name': 'Capitao Tchaka',
#      'release_date': '2016-01-28',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:0CZ4TsU38i1sLvxZ6osPdg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7iJl63aJyNd8C6NZlMv6kp'},
#       'href': 'https://api.spotify.com/v1/artists/7iJl63aJyNd8C6NZlMv6kp',
#       'id': '7iJl63aJyNd8C6NZlMv6kp',
#       'name': 'Tchakabum',
#       'type': 'artist',
#       'uri': 'spotify:artist:7iJl63aJyNd8C6NZlMv6kp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 275706,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITB881602605'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4ohps6RKcqCWMfK8GFcYE5'},
#     'href': 'https://api.spotify.com/v1/tracks/4ohps6RKcqCWMfK8GFcYE5',
#     'id': '4ohps6RKcqCWMfK8GFcYE5',
#     'is_local': False,
#     'name': 'Onda Onda (Olha a Onda)',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bd7faf16cfdd35132aec81ddaf567f5f9abd2ea3?cid=2cd9cbed41b142aa968a362050ad33a8',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4ohps6RKcqCWMfK8GFcYE5'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/53jJdyKveXstdRk1aTh1wN'},
#      'href': 'https://api.spotify.com/v1/albums/53jJdyKveXstdRk1aTh1wN',
#      'id': '53jJdyKveXstdRk1aTh1wN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b4ee4e413af05c58af144f9b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b4ee4e413af05c58af144f9b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b4ee4e413af05c58af144f9b',
#        'width': 64}],
#      'name': 'Transita con onda',
#      'release_date': '2021-04-02',
#      'release_date_precision': 'day',
#      'total_tracks': 26,
#      'type': 'album',
#      'uri': 'spotify:album:53jJdyKveXstdRk1aTh1wN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/07YUOmWljBTXwIseAUd9TW'},
#       'href': 'https://api.spotify.com/v1/artists/07YUOmWljBTXwIseAUd9TW',
#       'id': '07YUOmWljBTXwIseAUd9TW',
#       'name': 'Sebastian Yatra',
#       'type': 'artist',
#       'uri': 'spotify:artist:07YUOmWljBTXwIseAUd9TW'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 208080,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71804074'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1e5IRFcO9OltdZAfELXORW'},
#     'href': 'https://api.spotify.com/v1/tracks/1e5IRFcO9OltdZAfELXORW',
#     'id': '1e5IRFcO9OltdZAfELXORW',
#     'is_local': False,
#     'name': 'MANTRA',
#     'popularity': 6,
#     'preview_url': None,
#     'track_number': 25,
#     'type': 'track',
#     'uri': 'spotify:track:1e5IRFcO9OltdZAfELXORW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2dn7slANEuZTGyraHIhEg0'},
#        'href': 'https://api.spotify.com/v1/artists/2dn7slANEuZTGyraHIhEg0',
#        'id': '2dn7slANEuZTGyraHIhEg0',
#        'name': 'Axe Bahia',
#        'type': 'artist',
#        'uri': 'spotify:artist:2dn7slANEuZTGyraHIhEg0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0fwmxZ8eZDXvJYNLvxnp3r'},
#      'href': 'https://api.spotify.com/v1/albums/0fwmxZ8eZDXvJYNLvxnp3r',
#      'id': '0fwmxZ8eZDXvJYNLvxnp3r',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735552e8e70ab039d08e119cf4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025552e8e70ab039d08e119cf4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515552e8e70ab039d08e119cf4',
#        'width': 64}],
#      'name': 'Melhores Sucessos',
#      'release_date': '2008-12-12',
#      'release_date_precision': 'day',
#      'total_tracks': 50,
#      'type': 'album',
#      'uri': 'spotify:album:0fwmxZ8eZDXvJYNLvxnp3r'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2dn7slANEuZTGyraHIhEg0'},
#       'href': 'https://api.spotify.com/v1/artists/2dn7slANEuZTGyraHIhEg0',
#       'id': '2dn7slANEuZTGyraHIhEg0',
#       'name': 'Axe Bahia',
#       'type': 'artist',
#       'uri': 'spotify:artist:2dn7slANEuZTGyraHIhEg0'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'ZA',
#      'ZM'],
#     'disc_number': 1,
#     'duration_ms': 262608,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCADX1849248'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4IOL9xoyPvDQJobr1Bta5c'},
#     'href': 'https://api.spotify.com/v1/tracks/4IOL9xoyPvDQJobr1Bta5c',
#     'id': '4IOL9xoyPvDQJobr1Bta5c',
#     'is_local': False,
#     'name': 'Onda Onda',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5e3cc9c3931e59e83178e1efe51db5e2310ff975?cid=2cd9cbed41b142aa968a362050ad33a8',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:4IOL9xoyPvDQJobr1Bta5c'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/53jJdyKveXstdRk1aTh1wN'},
#      'href': 'https://api.spotify.com/v1/albums/53jJdyKveXstdRk1aTh1wN',
#      'id': '53jJdyKveXstdRk1aTh1wN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b4ee4e413af05c58af144f9b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b4ee4e413af05c58af144f9b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b4ee4e413af05c58af144f9b',
#        'width': 64}],
#      'name': 'Transita con onda',
#      'release_date': '2021-04-02',
#      'release_date_precision': 'day',
#      'total_tracks': 26,
#      'type': 'album',
#      'uri': 'spotify:album:53jJdyKveXstdRk1aTh1wN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/07YUOmWljBTXwIseAUd9TW'},
#       'href': 'https://api.spotify.com/v1/artists/07YUOmWljBTXwIseAUd9TW',
#       'id': '07YUOmWljBTXwIseAUd9TW',
#       'name': 'Sebastian Yatra',
#       'type': 'artist',
#       'uri': 'spotify:artist:07YUOmWljBTXwIseAUd9TW'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0BqURncJM5B1BBu7UM51eq'},
#       'href': 'https://api.spotify.com/v1/artists/0BqURncJM5B1BBu7UM51eq',
#       'id': '0BqURncJM5B1BBu7UM51eq',
#       'name': 'Guaynaa',
#       'type': 'artist',
#       'uri': 'spotify:artist:0BqURncJM5B1BBu7UM51eq'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 183240,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM72017740'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3x8F3ySwEQIzybElEMeDW0'},
#     'href': 'https://api.spotify.com/v1/tracks/3x8F3ySwEQIzybElEMeDW0',
#     'id': '3x8F3ySwEQIzybElEMeDW0',
#     'is_local': False,
#     'name': 'Chica Ideal',
#     'popularity': 4,
#     'preview_url': None,
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:3x8F3ySwEQIzybElEMeDW0'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5UvcXvhAizntaKn34sJH8v'},
#        'href': 'https://api.spotify.com/v1/artists/5UvcXvhAizntaKn34sJH8v',
#        'id': '5UvcXvhAizntaKn34sJH8v',
#        'name': 'Ondas Alfa',
#        'type': 'artist',
#        'uri': 'spotify:artist:5UvcXvhAizntaKn34sJH8v'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1Plb2yeUtniZAu1CrWCuad'},
#      'href': 'https://api.spotify.com/v1/albums/1Plb2yeUtniZAu1CrWCuad',
#      'id': '1Plb2yeUtniZAu1CrWCuad',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732ca29be3e2b7196bd38ea865',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022ca29be3e2b7196bd38ea865',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512ca29be3e2b7196bd38ea865',
#        'width': 64}],
#      'name': 'Ondas Cerebrales Para Estudiar (musica para concentrarse , musica para relajarse, musica para estudiar)',
#      'release_date': '2017-05-25',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1Plb2yeUtniZAu1CrWCuad'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5UvcXvhAizntaKn34sJH8v'},
#       'href': 'https://api.spotify.com/v1/artists/5UvcXvhAizntaKn34sJH8v',
#       'id': '5UvcXvhAizntaKn34sJH8v',
#       'name': 'Ondas Alfa',
#       'type': 'artist',
#       'uri': 'spotify:artist:5UvcXvhAizntaKn34sJH8v'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 73500,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITS781701323'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7BwtbfcQm6iQReER04CW84'},
#     'href': 'https://api.spotify.com/v1/tracks/7BwtbfcQm6iQReER04CW84',
#     'id': '7BwtbfcQm6iQReER04CW84',
#     'is_local': False,
#     'name': 'Ondas Alfa',
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/aa2c37a17e94f3b2f929eac1bace73eec87560c6?cid=2cd9cbed41b142aa968a362050ad33a8',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7BwtbfcQm6iQReER04CW84'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/53jJdyKveXstdRk1aTh1wN'},
#      'href': 'https://api.spotify.com/v1/albums/53jJdyKveXstdRk1aTh1wN',
#      'id': '53jJdyKveXstdRk1aTh1wN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b4ee4e413af05c58af144f9b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b4ee4e413af05c58af144f9b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b4ee4e413af05c58af144f9b',
#        'width': 64}],
#      'name': 'Transita con onda',
#      'release_date': '2021-04-02',
#      'release_date_precision': 'day',
#      'total_tracks': 26,
#      'type': 'album',
#      'uri': 'spotify:album:53jJdyKveXstdRk1aTh1wN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5DUlefCLzVRzNWaNURTFpK'},
#       'href': 'https://api.spotify.com/v1/artists/5DUlefCLzVRzNWaNURTFpK',
#       'id': '5DUlefCLzVRzNWaNURTFpK',
#       'name': 'Cali Y El Dandee',
#       'type': 'artist',
#       'uri': 'spotify:artist:5DUlefCLzVRzNWaNURTFpK'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5xSx2FM8mQnrfgM1QsHniB'},
#       'href': 'https://api.spotify.com/v1/artists/5xSx2FM8mQnrfgM1QsHniB',
#       'id': '5xSx2FM8mQnrfgM1QsHniB',
#       'name': 'Danna Paola',
#       'type': 'artist',
#       'uri': 'spotify:artist:5xSx2FM8mQnrfgM1QsHniB'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 174026,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM72015118'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1CcPw8uhf5wktLLsQ6T1fe'},
#     'href': 'https://api.spotify.com/v1/tracks/1CcPw8uhf5wktLLsQ6T1fe',
#     'id': '1CcPw8uhf5wktLLsQ6T1fe',
#     'is_local': False,
#     'name': 'Nada',
#     'popularity': 7,
#     'preview_url': None,
#     'track_number': 22,
#     'type': 'track',
#     'uri': 'spotify:track:1CcPw8uhf5wktLLsQ6T1fe'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5UvcXvhAizntaKn34sJH8v'},
#        'href': 'https://api.spotify.com/v1/artists/5UvcXvhAizntaKn34sJH8v',
#        'id': '5UvcXvhAizntaKn34sJH8v',
#        'name': 'Ondas Alfa',
#        'type': 'artist',
#        'uri': 'spotify:artist:5UvcXvhAizntaKn34sJH8v'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1Plb2yeUtniZAu1CrWCuad'},
#      'href': 'https://api.spotify.com/v1/albums/1Plb2yeUtniZAu1CrWCuad',
#      'id': '1Plb2yeUtniZAu1CrWCuad',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732ca29be3e2b7196bd38ea865',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022ca29be3e2b7196bd38ea865',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512ca29be3e2b7196bd38ea865',
#        'width': 64}],
#      'name': 'Ondas Cerebrales Para Estudiar (musica para concentrarse , musica para relajarse, musica para estudiar)',
#      'release_date': '2017-05-25',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1Plb2yeUtniZAu1CrWCuad'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5UvcXvhAizntaKn34sJH8v'},
#       'href': 'https://api.spotify.com/v1/artists/5UvcXvhAizntaKn34sJH8v',
#       'id': '5UvcXvhAizntaKn34sJH8v',
#       'name': 'Ondas Alfa',
#       'type': 'artist',
#       'uri': 'spotify:artist:5UvcXvhAizntaKn34sJH8v'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 105000,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITS781701331'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5bF72rEaAcLaEAkyFwVUZo'},
#     'href': 'https://api.spotify.com/v1/tracks/5bF72rEaAcLaEAkyFwVUZo',
#     'id': '5bF72rEaAcLaEAkyFwVUZo',
#     'is_local': False,
#     'name': 'Ondas Sonoras',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8081f43e18f58ff81e46369da7509ba90f10b3fb?cid=2cd9cbed41b142aa968a362050ad33a8',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:5bF72rEaAcLaEAkyFwVUZo'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1T9LdtwSTDoXrbkvHtKpGw'},
#        'href': 'https://api.spotify.com/v1/artists/1T9LdtwSTDoXrbkvHtKpGw',
#        'id': '1T9LdtwSTDoXrbkvHtKpGw',
#        'name': 'Onda Vaselina',
#        'type': 'artist',
#        'uri': 'spotify:artist:1T9LdtwSTDoXrbkvHtKpGw'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7fgHGpxFOYzXjITOZ2e2Ht'},
#      'href': 'https://api.spotify.com/v1/albums/7fgHGpxFOYzXjITOZ2e2Ht',
#      'id': '7fgHGpxFOYzXjITOZ2e2Ht',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738ff260da6818dd4c09e39231',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028ff260da6818dd4c09e39231',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518ff260da6818dd4c09e39231',
#        'width': 64}],
#      'name': 'Entrega Total',
#      'release_date': '1998',
#      'release_date_precision': 'year',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:7fgHGpxFOYzXjITOZ2e2Ht'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1T9LdtwSTDoXrbkvHtKpGw'},
#       'href': 'https://api.spotify.com/v1/artists/1T9LdtwSTDoXrbkvHtKpGw',
#       'id': '1T9LdtwSTDoXrbkvHtKpGw',
#       'name': 'Onda Vaselina',
#       'type': 'artist',
#       'uri': 'spotify:artist:1T9LdtwSTDoXrbkvHtKpGw'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 187666,
#     'explicit': False,
#     'external_ids': {'isrc': 'MXF149700127'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2S0XH9R1BVZhbcy7j9yQbx'},
#     'href': 'https://api.spotify.com/v1/tracks/2S0XH9R1BVZhbcy7j9yQbx',
#     'id': '2S0XH9R1BVZhbcy7j9yQbx',
#     'is_local': False,
#     'name': 'Te Quiero Tanto, Tanto',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/98c4cd96fff4b15ed1fda51d4f7f0b288a0f6512?cid=2cd9cbed41b142aa968a362050ad33a8',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:2S0XH9R1BVZhbcy7j9yQbx'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5UvcXvhAizntaKn34sJH8v'},
#        'href': 'https://api.spotify.com/v1/artists/5UvcXvhAizntaKn34sJH8v',
#        'id': '5UvcXvhAizntaKn34sJH8v',
#        'name': 'Ondas Alfa',
#        'type': 'artist',
#        'uri': 'spotify:artist:5UvcXvhAizntaKn34sJH8v'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1WLiuOQtqUJhxGog4iAXHA'},
#        'href': 'https://api.spotify.com/v1/artists/1WLiuOQtqUJhxGog4iAXHA',
#        'id': '1WLiuOQtqUJhxGog4iAXHA',
#        'name': 'Musica para Concentrarse',
#        'type': 'artist',
#        'uri': 'spotify:artist:1WLiuOQtqUJhxGog4iAXHA'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1PH7S6wAZIgfxmHsX1hutZ'},
#        'href': 'https://api.spotify.com/v1/artists/1PH7S6wAZIgfxmHsX1hutZ',
#        'id': '1PH7S6wAZIgfxmHsX1hutZ',
#        'name': 'Fondo de la lectura',
#        'type': 'artist',
#        'uri': 'spotify:artist:1PH7S6wAZIgfxmHsX1hutZ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5Yb67jazGGw1966L8v2T6n'},
#      'href': 'https://api.spotify.com/v1/albums/5Yb67jazGGw1966L8v2T6n',
#      'id': '5Yb67jazGGw1966L8v2T6n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736ca1e8895e41f5778e2793cf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026ca1e8895e41f5778e2793cf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516ca1e8895e41f5778e2793cf',
#        'width': 64}],
#      'name': 'Ondas Alfa: Ritmos binaurales, ondas theta y música ambiental para concentrarse, enfocarse, estudiar y leer, Vol. 2',
#      'release_date': '2021-04-06',
#      'release_date_precision': 'day',
#      'total_tracks': 26,
#      'type': 'album',
#      'uri': 'spotify:album:5Yb67jazGGw1966L8v2T6n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5UvcXvhAizntaKn34sJH8v'},
#       'href': 'https://api.spotify.com/v1/artists/5UvcXvhAizntaKn34sJH8v',
#       'id': '5UvcXvhAizntaKn34sJH8v',
#       'name': 'Ondas Alfa',
#       'type': 'artist',
#       'uri': 'spotify:artist:5UvcXvhAizntaKn34sJH8v'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1WLiuOQtqUJhxGog4iAXHA'},
#       'href': 'https://api.spotify.com/v1/artists/1WLiuOQtqUJhxGog4iAXHA',
#       'id': '1WLiuOQtqUJhxGog4iAXHA',
#       'name': 'Musica para Concentrarse',
#       'type': 'artist',
#       'uri': 'spotify:artist:1WLiuOQtqUJhxGog4iAXHA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1PH7S6wAZIgfxmHsX1hutZ'},
#       'href': 'https://api.spotify.com/v1/artists/1PH7S6wAZIgfxmHsX1hutZ',
#       'id': '1PH7S6wAZIgfxmHsX1hutZ',
#       'name': 'Fondo de la lectura',
#       'type': 'artist',
#       'uri': 'spotify:artist:1PH7S6wAZIgfxmHsX1hutZ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 119901,
#     'explicit': False,
#     'external_ids': {'isrc': 'USLZJ2123943'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/46vF0hviPEfjscODSu98Zh'},
#     'href': 'https://api.spotify.com/v1/tracks/46vF0hviPEfjscODSu98Zh',
#     'id': '46vF0hviPEfjscODSu98Zh',
#     'is_local': False,
#     'name': 'Ondas Alfa',
#     'popularity': 19,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1d657f7bb7e19a4aea3c33838b4c691dc7a87e31?cid=2cd9cbed41b142aa968a362050ad33a8',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:46vF0hviPEfjscODSu98Zh'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/53jJdyKveXstdRk1aTh1wN'},
#      'href': 'https://api.spotify.com/v1/albums/53jJdyKveXstdRk1aTh1wN',
#      'id': '53jJdyKveXstdRk1aTh1wN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b4ee4e413af05c58af144f9b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b4ee4e413af05c58af144f9b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b4ee4e413af05c58af144f9b',
#        'width': 64}],
#      'name': 'Transita con onda',
#      'release_date': '2021-04-02',
#      'release_date_precision': 'day',
#      'total_tracks': 26,
#      'type': 'album',
#      'uri': 'spotify:album:53jJdyKveXstdRk1aTh1wN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ackd5XprZEkH3McKbQD51'},
#       'href': 'https://api.spotify.com/v1/artists/1ackd5XprZEkH3McKbQD51',
#       'id': '1ackd5XprZEkH3McKbQD51',
#       'name': 'Juan Magán',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ackd5XprZEkH3McKbQD51'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1o9x7ez0NvhDb7gBqrYnUj'},
#       'href': 'https://api.spotify.com/v1/artists/1o9x7ez0NvhDb7gBqrYnUj',
#       'id': '1o9x7ez0NvhDb7gBqrYnUj',
#       'name': 'B-Case',
#       'type': 'artist',
#       'uri': 'spotify:artist:1o9x7ez0NvhDb7gBqrYnUj'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 202713,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5701800464'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5QVEN6ZF7U15cwBKRTf2GO'},
#     'href': 'https://api.spotify.com/v1/tracks/5QVEN6ZF7U15cwBKRTf2GO',
#     'id': '5QVEN6ZF7U15cwBKRTf2GO',
#     'is_local': False,
#     'name': 'Escondidos',
#     'popularity': 4,
#     'preview_url': None,
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:5QVEN6ZF7U15cwBKRTf2GO'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=onda+onda&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 46154}}

# %% [markdown]
# ## Twitter API

# %% [markdown]
# Install wrapper: `!pip install tweepy`

# %% [markdown]
# ### Read the docs
#
# - Twitter API: https://developer.twitter.com/en/docs
# - Getting started: https://developer.twitter.com/en/docs/basics/getting-started
# - Generate an APP
# - Get your KEYs and TOKENs
#
# - **READ the tweepy documentation**: http://tweepy.readthedocs.io/

# %% [markdown]
# https://developer.twitter.com/en/docs/labs/filtered-stream/quick-start

# %% [markdown]
# https://towardsdatascience.com/how-to-access-twitters-api-using-tweepy-5a13a206683b

# %%
import tweepy

API_KEY= os.getenv('API_KEY')
API_SECRET=os.getenv('API_SECRET')
ACCESS_TOKEN=os.getenv('ACCESS_TOKEN')
ACCESS_TOKEN_SECRET=os.getenv('ACCESS_TOKEN_SECRET')

auth = tweepy.OAuthHandler(API_KEY, API_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %% [markdown]
# ### Verify Credentials

# %%
try:
    api.verify_credentials()
    print("Authentication OK")
except:
    print("Error during authentication")
# Out:
# Authentication OK

# %% [markdown]
# ### Get user

# %%
user = api.get_user('andreaguiarr')

# %%
type(user)
# Out:
# tweepy.models.User

# %% [markdown]
# `user` will be an object. You'll have to learn how to handle it by searching for its methods and attributes.

# %% [markdown]
# ### ._json

# %%
user._json

# %% [markdown]
# ### Get user's friends list

# %%
user.friends_count

# %%
friends = user.friends()

# %% [markdown]
# ### Send a tweet

# %%
comment = '#acertômizeravi #chicletêro #eusôdabahia #cansado #Vamp_s2_Friends #xingandomuito https://www.youtube.com/watch?v=vePc5V4h_kg'
api.update_status(comment)

# %% [markdown]
# ### Get followers

# %%
followers = api.followers('jairbolsonaro', count=100)

# %%
len(followers)

# %% [markdown]
# ### My tweets

# %%
timeline = api.home_timeline()
timeline

# %%
for i in range(10):
    print(timeline[i]._json['text'])

# %% [markdown]
# ### Create friend

# %%
api.create_friendship('dnnetto')

# %% [markdown]
# ### search for keywords

# %%
posts = api.search(q="ironhack", lang="en", count=100)
len(posts)

# %%
posts[2]._json['text']

# %%
i = 5
print(posts[i]._json['text'])

print(posts[i]._json['entities']['hashtags'])

print(posts[i]._json['user']['name'])

# %%
import re

for post in posts:
    if len(post._json['entities']['hashtags']): 
        if re.search('.*scholarships.*', post._json['entities']['hashtags'][0]['text'], 
                     flags=re.IGNORECASE):
            print(post._json['user']['name'], '-', post._json['user']['location'], post._json['text'], '\n')

# %% [markdown]
# ### Get user's timeline

# %%
tweets = api.user_timeline(screen_name = 'realDonaldTrump', count=2000)

# %%
tweets[0]._json['text']

# %% [markdown]
# ----

# %% [markdown]
# `!pip install Goodreads`

# %%
from goodreads import client
gc = client.GoodreadsClient(os.getenv('goodreads_key'), 
                            os.getenv('goodreads_secret'))

# %%
book = gc.book(1)
book

# %%
type(book)

# %%
book.average_rating

# %%
book.title

# %%
book.similar_books

# %%
user = gc.user(3)

# %%
user.name

# %%
gc.find_groups("star wars")

# %% [markdown]
# ## Trello

# %%
from trello import TrelloClient

client = TrelloClient(
    api_key=os.getenv('trello_key'),
    api_secret=os.getenv('trello_secret'),
    token=os.getenv('trello_token'),
)

# %%
client.list_boards()

# %%
client.search('Parallel')

# %%
from trello.label import Label

# %%
label = Label(client, 1, 'test_label')

# %%
card = client.search('Parallel')[0]

# %%
try:
    [checklist.delete() for checklist in card.checklists]
    print('Deleted')
except:
    print('No checklists to delete')

# %%
card.add_checklist('Test', ['a','b','c'], itemstates=[False, True, False])

# %%
client.add_board('New Board')
