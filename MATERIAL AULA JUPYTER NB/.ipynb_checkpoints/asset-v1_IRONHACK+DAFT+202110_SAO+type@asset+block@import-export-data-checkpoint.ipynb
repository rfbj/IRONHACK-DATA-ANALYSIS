# %% [markdown]
# # Pandas: Importing and Exporting

# %% [markdown]
# ## Importing and Exporting DELIMITED FILES

# %% [markdown]
# ### Comma separated values (CSV) files
#
# A file that is separated (or delimited) by commas (or anything else)

# %% [markdown]
# Example:
#
# **-- comma separated file --**
#
#     name,year,value
#     Andre,2020,100
#     Fernanda,1900,1
#
# **-- tab separated file --**
#
#     name    year    value
#     Andre    2020    100
#     Fernanda    1900    1
#
# **-- tab separated file (another way) --**
#
#     name\tyear\tvalue
#     Andre\t2020\t100
#     Fernanda\t1900\t1
#
# **-- hash separated file --**
#
#     name#year#value
#     Andre#2020#100
#     Fernanda#1900#1
#
# **-- pipe separated file --**
#
#     name|year|value
#     Andre|2020|100
#     Fernanda|1900|1
#
#     ...

# %% [markdown]
# # Import comma-separated values file - csv (the default)

# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\raian\\OneDrive\\Documentos\\IronHack\\ironhack-course-before-class\\ironhack-course\\full-time\\week2\\3-pandas-import-export'

# %%
'C:\\Users\\raian\\OneDrive\\Documentos\\IronHack\\ironhack-course-before-class\\ironhack-course\\full-time\\week2\\3-pandas-import-export'.replace('\\','/')
# Out:
# 'C:/Users/raian/OneDrive/Documentos/IronHack/ironhack-course-before-class/ironhack-course/full-time/week2/3-pandas-import-export'

# %%
# relative path
df = pd.read_csv('data/vehicles.csv')

# %%
df
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %%
data = pd.read_csv('C:/Users/raian/OneDrive/Documentos/IronHack/ironhack-course-before-class/ironhack-course/full-time/week2/3-pandas-import-export/data/vehicles.csv')

# %%
data
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %%
df.head()
# Out:
#          Make              Model  Year  Engine Displacement  Cylinders  \
# 0  AM General  DJ Po Vehicle 2WD  1984                  2.5        4.0
#
#       Transmission     Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950

# %%
df.tail()
# Out:
#         Make         Model  Year  Engine Displacement  Cylinders  \
# 35947  smart  fortwo coupe  2013                  1.0        3.0
# 35948  smart  fortwo coupe  2014                  1.0        3.0
# 35949  smart  fortwo coupe  2015                  1.0        3.0
# 35950  smart  fortwo coupe  2016                  0.9        3.0
# 35951  smart  fortwo coupe  2016                  0.9        3.0
#
#        Transmission        Drivetrain Vehicle Class Fuel Type  \
# 35947     Auto(AM5)  Rear-Wheel Drive   Two Seaters   Premium
# 35948     Auto(AM5)  Rear-Wheel Drive   Two Seaters   Premium
# 35949     Auto(AM5)  Rear-Wheel Drive   Two Seaters   Premium
# 35950     Auto(AM6)  Rear-Wheel Drive   Two Seaters   Premium
# 35951  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 35947           9.155833        34           38            36
# 35948           9.155833        34           38            36
# 35949           9.155833        34           38            36
# 35950           9.155833        34           39            36
# 35951           9.417429        32           39            35
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year
# 35947                    244.0            1100
# 35948                    243.0            1100
# 35949                    244.0            1100
# 35950                    246.0            1100
# 35951                    255.0            1150

# %%
df.describe()
# Out:
#               Year  Engine Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000         35952.000000  35952.000000       35952.000000
# mean    2000.71640             3.338493      5.765076          17.609056
# std       10.08529             1.359395      1.755268           4.467283
# min     1984.00000             0.600000      2.000000           0.060000
# 25%     1991.00000             2.200000      4.000000          14.699423
# 50%     2001.00000             3.000000      6.000000          17.347895
# 75%     2010.00000             4.300000      6.000000          20.600625
# max     2017.00000             8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# min        6.000000      9.000000      7.000000                37.000000
# 25%       15.000000     20.000000     16.000000               395.000000
# 50%       17.000000     24.000000     19.000000               467.736842
# 75%       20.000000     27.000000     23.000000               555.437500
# max       58.000000     61.000000     56.000000              1269.571429
#
#        Fuel Cost/Year
# count    35952.000000
# mean      1892.598465
# std        506.958627
# min        600.000000
# 25%       1500.000000
# 50%       1850.000000
# 75%       2200.000000
# max       5800.000000

# %%
# relative path
pd.read_csv('../3-pandas-import-export/data/vehicles.csv')
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %% [markdown]
# In this way, the `pd.read_csv()` method is just outputing the results on screen.
#
# If I wanted to store it in a variable I would have to **assign** this result into a variable

# %%
import os

# %%
os.listdir('../3-pandas-import-export/data')
# Out:
# ['image.png', 'vehicles.csv']

# %%
pd.read_csv('data/vehicles.csv')
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %%
vehicles = pd.read_csv('data/vehicles.csv')

# %%
vehicles.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# ## Import tab-delimited file

# %%
# ParserError

pd.read_csv('data/vehicles_tab.txt')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-36-a5790c2e95b9> in <module>
#       1 # ParserError
#       2
# ----> 3 pd.read_csv('data/vehicles_tab.txt')
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 4319, saw 2

# %%
pd.read_csv('data/vehicles_tab.txt', sep=';')
# Out:
#       Make\tModel\tYear\tEngine Displacement\tCylinders\tTransmission\tDrivetrain\tVehicle Class\tFuel Type\tFuel Barrels/Year\tCity MPG\tHighway MPG\tCombined MPG\tCO2 Emission Grams/Mile\tFuel Cost/Year
# 0      AM General\tDJ Po Vehicle 2WD\t1984\t2.5\t4.0\...
# 1      AM General\tFJ8c Post Office\t1984\t4.2\t6.0\t...
# 2      AM General\tPost Office DJ5 2WD\t1985\t2.5\t4....
# 3      AM General\tPost Office DJ8 2WD\t1985\t4.2\t6....
# 4      ASC Incorporated\tGNX\t1987\t3.8\t6.0\tAutomat...
# ...                                                  ...
# 35947  smart\tfortwo coupe\t2013\t1.0\t3.0\tAuto(AM5)...
# 35948  smart\tfortwo coupe\t2014\t1.0\t3.0\tAuto(AM5)...
# 35949  smart\tfortwo coupe\t2015\t1.0\t3.0\tAuto(AM5)...
# 35950  smart\tfortwo coupe\t2016\t0.9\t3.0\tAuto(AM6)...
# 35951  smart\tfortwo coupe\t2016\t0.9\t3.0\tManual 5-...
#
# [35952 rows x 1 columns]

# %%
pd.read_csv('data/vehicles_tab.txt', sep='\t')
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %% [markdown]
# ## Import pipe delimited file

# %%
pd.read_csv('data/vehicles_pipe.txt')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-39-c20bed0c7456> in <module>
# ----> 1 pd.read_csv('data/vehicles_pipe.txt')
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 4319, saw 2

# %%
pd.read_csv('data/vehicles_pipe.txt', sep=';')
# Out:
#       Make|Model|Year|Engine Displacement|Cylinders|Transmission|Drivetrain|Vehicle Class|Fuel Type|Fuel Barrels/Year|City MPG|Highway MPG|Combined MPG|CO2 Emission Grams/Mile|Fuel Cost/Year
# 0      AM General|DJ Po Vehicle 2WD|1984|2.5|4.0|Auto...
# 1      AM General|FJ8c Post Office|1984|4.2|6.0|Autom...
# 2      AM General|Post Office DJ5 2WD|1985|2.5|4.0|Au...
# 3      AM General|Post Office DJ8 2WD|1985|4.2|6.0|Au...
# 4      ASC Incorporated|GNX|1987|3.8|6.0|Automatic 4-...
# ...                                                  ...
# 35947  smart|fortwo coupe|2013|1.0|3.0|Auto(AM5)|Rear...
# 35948  smart|fortwo coupe|2014|1.0|3.0|Auto(AM5)|Rear...
# 35949  smart|fortwo coupe|2015|1.0|3.0|Auto(AM5)|Rear...
# 35950  smart|fortwo coupe|2016|0.9|3.0|Auto(AM6)|Rear...
# 35951  smart|fortwo coupe|2016|0.9|3.0|Manual 5-spd|R...
#
# [35952 rows x 1 columns]

# %%
df = pd.read_csv('data/vehicles_pipe.txt', sep='|')
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# ## Import hash delimited file

# %%
# hash
df = pd.read_csv('data/vehicles_hash.txt', sep='#')
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# # Importing files from URLs

# %% [markdown]
# pd.Example: https://github.com/rfordatascience/tidytuesday

# %%
#pd.options.display.max_rows=5
#pd.options.display.max_columns=99

# %%
df = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-07-07/coffee_ratings.csv')
df.head()
# Out:
#    total_cup_points  species                     owner country_of_origin  \
# 0             90.58  Arabica                 metad plc          Ethiopia
# 1             89.92  Arabica                 metad plc          Ethiopia
# 2             89.75  Arabica  grounds for health admin         Guatemala
# 3             89.00  Arabica       yidnekachew dabessa          Ethiopia
# 4             88.83  Arabica                 metad plc          Ethiopia
#
#                                   farm_name lot_number       mill ico_number  \
# 0                                 metad plc        NaN  metad plc  2014/2015
# 1                                 metad plc        NaN  metad plc  2014/2015
# 2  san marcos barrancas "san cristobal cuch        NaN        NaN        NaN
# 3     yidnekachew dabessa coffee plantation        NaN    wolensu        NaN
# 4                                 metad plc        NaN  metad plc  2014/2015
#
#                                  company       altitude        region  \
# 0      metad agricultural developmet plc      1950-2200  guji-hambela
# 1      metad agricultural developmet plc      1950-2200  guji-hambela
# 2                                    NaN  1600 - 1800 m           NaN
# 3  yidnekachew debessa coffee plantation      1800-2200        oromia
# 4      metad agricultural developmet plc      1950-2200  guji-hambela
#
#                                 producer  number_of_bags bag_weight  \
# 0                              METAD PLC             300      60 kg
# 1                              METAD PLC             300      60 kg
# 2                                    NaN               5          1
# 3  Yidnekachew Dabessa Coffee Plantation             320      60 kg
# 4                              METAD PLC             300      60 kg
#
#                    in_country_partner harvest_year      grading_date  \
# 0  METAD Agricultural Development plc         2014   April 4th, 2015
# 1  METAD Agricultural Development plc         2014   April 4th, 2015
# 2        Specialty Coffee Association          NaN    May 31st, 2010
# 3  METAD Agricultural Development plc         2014  March 26th, 2015
# 4  METAD Agricultural Development plc         2014   April 4th, 2015
#
#                     owner_1  variety processing_method  aroma  flavor  \
# 0                 metad plc      NaN      Washed / Wet   8.67    8.83
# 1                 metad plc    Other      Washed / Wet   8.75    8.67
# 2  Grounds for Health Admin  Bourbon               NaN   8.42    8.50
# 3       Yidnekachew Dabessa      NaN     Natural / Dry   8.17    8.58
# 4                 metad plc    Other      Washed / Wet   8.25    8.50
#
#    aftertaste  acidity  body  balance  uniformity  clean_cup  sweetness  \
# 0        8.67     8.75  8.50     8.42        10.0       10.0       10.0
# 1        8.50     8.58  8.42     8.42        10.0       10.0       10.0
# 2        8.42     8.42  8.33     8.42        10.0       10.0       10.0
# 3        8.42     8.42  8.50     8.25        10.0       10.0       10.0
# 4        8.25     8.50  8.42     8.33        10.0       10.0       10.0
#
#    cupper_points  moisture  category_one_defects  quakers  color  \
# 0           8.75      0.12                     0      0.0  Green
# 1           8.58      0.12                     0      0.0  Green
# 2           9.25      0.00                     0      0.0    NaN
# 3           8.67      0.11                     0      0.0  Green
# 4           8.58      0.12                     0      0.0  Green
#
#    category_two_defects        expiration                  certification_body  \
# 0                     0   April 3rd, 2016  METAD Agricultural Development plc
# 1                     1   April 3rd, 2016  METAD Agricultural Development plc
# 2                     0    May 31st, 2011        Specialty Coffee Association
# 3                     2  March 25th, 2016  METAD Agricultural Development plc
# 4                     2   April 3rd, 2016  METAD Agricultural Development plc
#
#                       certification_address  \
# 0  309fcf77415a3661ae83e027f7e5f05dad786e44
# 1  309fcf77415a3661ae83e027f7e5f05dad786e44
# 2  36d0d00a3724338ba7937c52a378d085f2172daa
# 3  309fcf77415a3661ae83e027f7e5f05dad786e44
# 4  309fcf77415a3661ae83e027f7e5f05dad786e44
#
#                       certification_contact unit_of_measurement  \
# 0  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 2  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 3  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 4  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
#
#    altitude_low_meters  altitude_high_meters  altitude_mean_meters
# 0               1950.0                2200.0                2075.0
# 1               1950.0                2200.0                2075.0
# 2               1600.0                1800.0                1700.0
# 3               1800.0                2200.0                2000.0
# 4               1950.0                2200.0                2075.0

# %%
df = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-01-14/passwords.csv')
df.describe()
# Out:
#              rank       value  offline_crack_sec    rank_alt    strength  \
# count  500.000000  500.000000       5.000000e+02  500.000000  500.000000
# mean   250.500000    5.602660       5.000096e-01  251.224000    7.432000
# std    144.481833    8.436005       2.658132e+00  145.052163    5.415536
# min      1.000000    1.290000       1.110000e-07    1.000000    0.000000
# 25%    125.750000    3.430000       3.210000e-03  125.750000    6.000000
# 50%    250.500000    3.720000       3.210000e-03  251.500000    7.000000
# 75%    375.250000    3.720000       8.350000e-02  376.250000    8.000000
# max    500.000000   92.270000       2.927000e+01  502.000000   48.000000
#
#         font_size
# count  500.000000
# mean    10.298000
# std      3.651282
# min      0.000000
# 25%     10.000000
# 50%     11.000000
# 75%     11.000000
# max     28.000000

# %% [markdown]
# ## Problems you may encounter: Encoding
#
# `encoding` refers to how the strings are represented under the hood
#
# - specifying
# ```python
# encoding = 'latin1'
# ```
# usually handles problems refering to strings with accents

# %%
pd.read_csv('data/CSV.8859-1.csv', )
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe1 in position 1: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-83-1df8b2be8af3> in <module>
# ----> 1 pd.read_csv('data/CSV.8859-1.csv', )
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1194     def read(self, nrows=None):
#    1195         nrows = _validate_integer("nrows", nrows)
# -> 1196         ret = self._engine.read(nrows)
#    1197
#    1198         # May alter columns / col_dict
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2153     def read(self, nrows=None):
#    2154         try:
# -> 2155             data = self._reader.read(nrows)
#    2156         except StopIteration:
#    2157             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe1 in position 1: invalid continuation byte

# %%
df = pd.read_csv('data/CSV.8859-1.csv', encoding='latin1', sep=';')

# %%
df
# Out:
#           Data Projeto(s)    Ini    Ter  Horas  \
# 0   qui, 02/01        GTE  11:30  12:00  00:30
# 1   qui, 02/01        GTE  13:00  13:30  00:30
# 2   qui, 02/01        GTE  13:30  14:00  00:30
# 3   qui, 02/01   GTE - FC  14:00  15:00  01:00
# 4   qui, 02/01        GTE  15:00  15:30  00:30
# ..         ...        ...    ...    ...    ...
# 93  qua, 29/01    PRODESP  16:30  17:30  01:00
# 94  qui, 30/01    PRODESP  14:00  18:00  04:00
# 95  sex, 31/01         RS  10:30  12:00  01:30
# 96  sex, 31/01        GTE  12:00  12:30  00:30
# 97  sex, 31/01    PRODESP  13:30  14:30  01:00
#
#                               Atividade  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0               Tarefas administrativas         NaN         NaN         NaN
# 1                  Apontamento de horas         NaN         NaN         NaN
# 2               Tarefas administrativas         NaN         NaN         NaN
# 3   Troubleshooting Contrato X Rubricas         NaN         NaN         NaN
# 4               Tarefas administrativas         NaN         NaN         NaN
# ..                                  ...         ...         ...         ...
# 93                       Sistemas APESP         NaN         NaN         NaN
# 94                       Sistemas APESP         NaN         NaN         NaN
# 95                  Revisão query Inova         NaN         NaN         NaN
# 96              Tarefas administrativas         NaN         NaN         NaN
# 97                       Sistemas APESP         NaN         NaN         NaN
#
#     Unnamed: 9
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 93         NaN
# 94         NaN
# 95         NaN
# 96         NaN
# 97         NaN
#
# [98 rows x 10 columns]

# %% [markdown]
# # Importing Excel Files

# %%
# read_csv wont work here
pd.read_csv('data/vehicles.xlsx', encoding='latin1', sep=';')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-43-50ad2fba98b8> in <module>
#       1 # read_csv wont work here
# ----> 2 pd.read_csv('data/vehicles.xlsx', encoding='latin1', sep=';')
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     458
#     459     try:
# --> 460         data = parser.read(nrows)
#     461     finally:
#     462         parser.close()
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1196     def read(self, nrows=None):
#    1197         nrows = _validate_integer("nrows", nrows)
# -> 1198         ret = self._engine.read(nrows)
#    1199
#    1200         # May alter columns / col_dict
#
# c:\users\raian\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2155     def read(self, nrows=None):
#    2156         try:
# -> 2157             data = self._reader.read(nrows)
#    2158         except StopIteration:
#    2159             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 3 fields in line 22, saw 5

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.9
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_excel('data/vehicles.xlsx',engine = 'openpyxl')
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0              4  Automatic 3-spd     2-Wheel Drive
# 1              6  Automatic 3-spd     2-Wheel Drive
# 2              4  Automatic 3-spd  Rear-Wheel Drive
# 3              6  Automatic 3-spd  Rear-Wheel Drive
# 4              6  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947          3        Auto(AM5)  Rear-Wheel Drive
# 35948          3        Auto(AM5)  Rear-Wheel Drive
# 35949          3        Auto(AM5)  Rear-Wheel Drive
# 35950          3        Auto(AM6)  Rear-Wheel Drive
# 35951          3     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %% [markdown]
# ## Read from specific excel sheet

# %%
df_excel = pd.read_excel('data/dados_artigo1.xlsx',None)
#df['PT']

# %%
df_excel['PT'].head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0         NaN  C1 Entrada  T1 Entrada   C1 Saída   T1 Saída  C2 Entrada
# 1         NaN         NaN         NaN        NaN        NaN         NaN
# 2         NaN         NaN         NaN        NaN        NaN         NaN
# 3         1.0       0.274       0.234       0.37      0.126       0.232
# 4         2.0       0.179       0.159      0.366      0.376       0.167
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  ... Unnamed: 19  \
# 0  T2 Entrada   C2 Saída   T2 Saída  C3 Entrada  ...         T10
# 1         NaN        NaN        NaN         NaN  ...         NaN
# 2         NaN        NaN        NaN         NaN  ...         NaN
# 3       0.244      0.065      0.088       0.227  ...    61.23348
# 4       0.152        0.1      0.146       0.169  ...   61.881188
#
#   Porc_remocao_macrofita Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24  \
# 0                     T3          T7         T10         NaN         NaN
# 1                    NaN         NaN         NaN         NaN         NaN
# 2                    NaN         NaN         NaN         NaN         NaN
# 3              46.153846           0           0         wet         NaN
# 4                      0           0   41.762845         wet         NaN
#
#    Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28
# 0  Temperatura         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3     21.07143         wet    21.81488         dry
# 4     22.18036         wet    21.18214         dry
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Extra: merged cells

# %%
pd.options.display.max_columns = 99

# %%
excel = pd.read_excel('data/dados_artigo1.xlsx',None)
excel.keys()
# Out:
# dict_keys(['Sheet1', 'PT', 'PT e NT na planta', 'PO4', 'Precipitation', 'Irradiacao Solar', 'DBO', 'NT', 'COR', 'TURBIDEZ', 'SST', 'PCA', 'dataset', 'PCA2', 'dinamica'])

# %%
pd.read_excel('data/dados_artigo1.xlsx', sheet_name='PT')
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0          NaN  C1 Entrada  T1 Entrada   C1 Saída   T1 Saída  C2 Entrada
# 1          NaN         NaN         NaN        NaN        NaN         NaN
# 2          NaN         NaN         NaN        NaN        NaN         NaN
# 3          1.0       0.274       0.234       0.37      0.126       0.232
# 4          2.0       0.179       0.159      0.366      0.376       0.167
# 5          3.0       1.852       3.072      0.342      0.236       1.627
# 6          4.0       1.042       1.087      0.178      0.103       1.099
# 7          5.0       0.247       0.224      0.162      0.108       0.249
# 8          6.0       1.037       1.982      0.176       0.03       1.037
# 9          7.0       0.699       0.849      0.294      0.123       0.739
# 10         8.0       0.264       0.279      0.228      0.126       0.232
# 11         9.0       0.532       0.557      0.243      0.065       0.607
# 12        10.0       0.069       0.113      0.017      0.014       0.063
# 13        11.0       2.883      13.923      1.023      0.399       2.103
# 14        12.0       2.313       3.648      1.047      0.263       2.343
# 15        13.0       0.423       0.438      1.426      0.171       0.461
# 16        14.0       2.216       3.858      0.918      0.369       2.336
# 17        15.0       4.691       4.721      1.039      0.468       4.758
# 18        16.0       4.391       4.323      0.888      0.827       4.593
# 19        17.0       7.421       7.466      0.583      0.056       6.746
# 20        18.0       0.483       0.476      0.425      0.071       0.551
# 21        19.0       0.573       0.858      0.297      0.525       0.633
# 22        20.0       0.596       0.678      0.185      0.554       0.596
# 23        21.0       0.612       0.605      0.564      0.218       0.552
# 24        22.0        1.49       1.385      0.747          0        1.46
# 25        23.0       0.905        0.89      0.903      0.301       0.965
.00  Arabica       yidnekachew dabessa          Ethiopia
# 4             88.83  Arabica                 metad plc          Ethiopia
#
#                                   farm_name lot_number       mill ico_number  \
# 0                                 metad plc        NaN  metad plc  2014/2015
# 1                                 metad plc        NaN  metad plc  2014/2015
# 2  san marcos barrancas "san cristobal cuch        NaN        NaN        NaN
# 3     yidnekachew dabessa coffee plantation        NaN    wolensu        NaN
# 4                                 metad plc        NaN  metad plc  2014/2015
#
#                                  company       altitude        region  \
# 0      metad agricultural developmet plc      1950-2200  guji-hambela
# 1      metad agricultural developmet plc      1950-2200  guji-hambela
# 2                                    NaN  1600 - 1800 m           NaN
# 3  yidnekachew debessa coffee plantation      1800-2200        oromia
# 4      metad agricultural developmet plc      1950-2200  guji-hambela
#
#                                 producer  number_of_bags bag_weight  \
# 0                              METAD PLC             300      60 kg
# 1                              METAD PLC             300      60 kg
# 2                                    NaN               5          1
# 3  Yidnekachew Dabessa Coffee Plantation             320      60 kg
# 4                              METAD PLC             300      60 kg
#
#                    in_country_partner harvest_year      grading_date  \
# 0  METAD Agricultural Development plc         2014   April 4th, 2015
# 1  METAD Agricultural Development plc         2014   April 4th, 2015
# 2        Specialty Coffee Association          NaN    May 31st, 2010
# 3  METAD Agricultural Development plc         2014  March 26th, 2015
# 4  METAD Agricultural Development plc         2014   April 4th, 2015
#
#                     owner_1  variety processing_method  aroma  flavor  \
# 0                 metad plc      NaN      Washed / Wet   8.67    8.83
# 1                 metad plc    Other      Washed / Wet   8.75    8.67
# 2  Grounds for Health Admin  Bourbon               NaN   8.42    8.50
# 3       Yidnekachew Dabessa      NaN     Natural / Dry   8.17    8.58
# 4                 metad plc    Other      Washed / Wet   8.25    8.50
#
#    aftertaste  acidity  body  balance  uniformity  clean_cup  sweetness  \
# 0        8.67     8.75  8.50     8.42        10.0       10.0       10.0
# 1        8.50     8.58  8.42     8.42        10.0       10.0       10.0
# 2        8.42     8.42  8.33     8.42        10.0       10.0       10.0
# 3        8.42     8.42  8.50     8.25        10.0       10.0       10.0
# 4        8.25     8.50  8.42     8.33        10.0       10.0       10.0
#
#    cupper_points  moisture  category_one_defects  quakers  color  \
# 0           8.75      0.12                     0      0.0  Green
# 1           8.58      0.12                     0      0.0  Green
# 2           9.25      0.00                     0      0.0    NaN
# 3           8.67      0.11                     0      0.0  Green
# 4           8.58      0.12                     0      0.0  Green
#
#    category_two_defects        expiration                  certification_body  \
# 0                     0   April 3rd, 2016  METAD Agricultural Development plc
# 1                     1   April 3rd, 2016  METAD Agricultural Development plc
# 2                     0    May 31st, 2011        Specialty Coffee Association
# 3                     2  March 25th, 2016  METAD Agricultural Development plc
# 4                     2   April 3rd, 2016  METAD Agricultural Development plc
#
#                       certification_address  \
# 0  309fcf77415a3661ae83e027f7e5f05dad786e44
# 1  309fcf77415a3661ae83e027f7e5f05dad786e44
# 2  36d0d00a3724338ba7937c52a378d085f2172daa
# 3  309fcf77415a3661ae83e027f7e5f05dad786e44
# 4  309fcf77415a3661ae83e027f7e5f05dad786e44
#
#                       certification_contact unit_of_measurement  \
# 0  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 2  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 3  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 4  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
#
#    altitude_low_meters  altitude_high_meters  altitude_mean_meters
# 0               1950.0                2200.0                2075.0
# 1               1950.0                2200.0                2075.0
# 2               1600.0                1800.0                1700.0
# 3               1800.0                2200.0                2000.0
# 4               1950.0                2200.0                2075.0

# %%
df.to_csv('data/teste1.csv')

# %%
pd.read_csv('data/teste1.csv').drop('Unnamed: 0',axis=1)
# Out:
#       total_cup_points  species                     owner country_of_origin  \
# 0                90.58  Arabica                 metad plc          Ethiopia
# 1                89.92  Arabica                 metad plc          Ethiopia
# 2                89.75  Arabica  grounds for health admin         Guatemala
# 3                89.00  Arabica       yidnekachew dabessa          Ethiopia
# 4                88.83  Arabica                 metad plc          Ethiopia
# ...                ...      ...                       ...               ...
# 1334             78.75  Robusta               luis robles           Ecuador
# 1335             78.08  Robusta               luis robles           Ecuador
# 1336             77.17  Robusta               james moore     United States
# 1337             75.08  Robusta             cafe politico             India
# 1338             73.75  Robusta             cafe politico           Vietnam
#
#                                      farm_name lot_number            mill  \
# 0                                    metad plc        NaN       metad plc
# 1                                    metad plc        NaN       metad plc
# 2     san marcos barrancas "san cristobal cuch        NaN             NaN
# 3        yidnekachew dabessa coffee plantation        NaN         wolensu
# 4                                    metad plc        NaN       metad plc
# ...                                        ...        ...             ...
# 1334                                 robustasa   Lavado 1     our own lab
# 1335                                 robustasa   Lavado 3  own laboratory
# 1336                           fazenda cazengo        NaN    cafe cazengo
# 1337                                       NaN        NaN             NaN
# 1338                                       NaN        NaN             NaN
#
#              ico_number                                company       altitude  \
# 0             2014/2015      metad agricultural developmet plc      1950-2200
# 1             2014/2015      metad agricultural developmet plc      1950-2200
# 2                   NaN                                    NaN  1600 - 1800 m
# 3                   NaN  yidnekachew debessa coffee plantation      1800-2200
# 4             2014/2015      metad agricultural developmet plc      1950-2200
# ...                 ...                                    ...            ...
# 1334                NaN                              robustasa            NaN
# 1335                NaN                              robustasa             40
# 1336                NaN                global opportunity fund     795 meters
# 1337  14-1118-2014-0087                          cafe politico            NaN
# 1338                NaN                          cafe politico            NaN
#
#                              region                               producer  \
# 0                      guji-hambela                              METAD PLC
# 1                      guji-hambela                              METAD PLC
# 2                               NaN                                    NaN
# 3                            oromia  Yidnekachew Dabessa Coffee Plantation
# 4                      guji-hambela                              METAD PLC
# ...                             ...                                    ...
# 1334               san juan, playas          Café Robusta del Ecuador S.A.
# 1335               san juan, playas          Café Robusta del Ecuador S.A.
# 1336  kwanza norte province, angola                           Cafe Cazengo
# 1337                            NaN                                    NaN
# 1338                            NaN                                    NaN
#
#       number_of_bags bag_weight                  in_country_partner  \
# 0                300      60 kg  METAD Agricultural Development plc
# 1                300      60 kg  METAD Agricultural Development plc
# 2                  5          1        Specialty Coffee Association
# 3                320      60 kg  METAD Agricultural Development plc
# 4                300      60 kg  METAD Agricultural Development plc
# ...              ...        ...                                 ...
# 1334               1       2 kg        Specialty Coffee Association
# 1335               1       2 kg        Specialty Coffee Association
# 1336               1       1 kg        Specialty Coffee Association
# 1337               1      5 lbs        Specialty Coffee Association
# 1338               1      5 lbs        Specialty Coffee Association
#
#      harvest_year         grading_date                   owner_1  variety  \
# 0            2014      April 4th, 2015                 metad plc      NaN
# 1            2014      April 4th, 2015                 metad plc    Other
# 2             NaN       May 31st, 2010  Grounds for Health Admin  Bourbon
# 3            2014     March 26th, 2015       Yidnekachew Dabessa      NaN
# 4            2014      April 4th, 2015                 metad plc    Other
# ...           ...                  ...                       ...      ...
# 1334         2016   January 19th, 2016               Luis Robles      NaN
# 1335         2016   January 19th, 2016               Luis Robles      NaN
# 1336         2014  December 23rd, 2014               James Moore      NaN
# 1337         2013    August 25th, 2014             Cafe Politico      NaN
# 1338         2013    August 25th, 2014             Cafe Politico      NaN
#
#      processing_method  aroma  flavor  aftertaste  acidity  body  balance  \
# 0         Washed / Wet   8.67    8.83        8.67     8.75  8.50     8.42
# 1         Washed / Wet   8.75    8.67        8.50     8.58  8.42     8.42
# 2                  NaN   8.42    8.50        8.42     8.42  8.33     8.42
# 3        Natural / Dry   8.17    8.58        8.42     8.42  8.50     8.25
# 4         Washed / Wet   8.25    8.50        8.25     8.50  8.42     8.33
# ...                ...    ...     ...         ...      ...   ...      ...
# 1334               NaN   7.75    7.58        7.33     7.58  5.08     7.83
# 1335               NaN   7.50    7.67        7.75     7.75  5.17     5.25
# 1336     Natural / Dry   7.33    7.33        7.17     7.42  7.50     7.17
# 1337     Natural / Dry   7.42    6.83        6.75     7.17  7.25     7.00
# 1338     Natural / Dry   6.75    6.67        6.50     6.83  6.92     6.83
#
#       uniformity  clean_cup  sweetness  cupper_points  moisture  \
# 0          10.00      10.00      10.00           8.75      0.12
# 1          10.00      10.00      10.00           8.58      0.12
# 2          10.00      10.00      10.00           9.25      0.00
# 3          10.00      10.00      10.00           8.67      0.11
# 4          10.00      10.00      10.00           8.58      0.12
# ...          ...        ...        ...            ...       ...
# 1334       10.00      10.00       7.75           7.83      0.00
# 1335       10.00      10.00       8.42           8.58      0.00
# 1336        9.33       9.33       7.42           7.17      0.00
# 1337        9.33       9.33       7.08           6.92      0.10
# 1338        9.33       9.33       6.67           7.92      0.12
#
#       category_one_defects  quakers       color  category_two_defects  \
# 0                        0      0.0       Green                     0
# 1                        0      0.0       Green                     1
# 2                        0      0.0         NaN                     0
# 3                        0      0.0       Green                     2
# 4                        0      0.0       Green                     2
# ...                    ...      ...         ...                   ...
# 1334                     0      0.0  Blue-Green                     1
# 1335                     0      0.0  Blue-Green                     0
# 1336                     0      0.0         NaN                     6
# 1337                    20      0.0       Green                     1
# 1338                    63      0.0        None                     9
#
#                expiration                  certification_body  \
# 0         April 3rd, 2016  METAD Agricultural Development plc
# 1         April 3rd, 2016  METAD Agricultural Development plc
# 2          May 31st, 2011        Specialty Coffee Association
# 3        March 25th, 2016  METAD Agricultural Development plc
# 4         April 3rd, 2016  METAD Agricultural Development plc
# ...                   ...                                 ...
# 1334   January 18th, 2017        Specialty Coffee Association
# 1335   January 18th, 2017        Specialty Coffee Association
# 1336  December 23rd, 2015        Specialty Coffee Association
# 1337    August 25th, 2015        Specialty Coffee Association
# 1338    August 25th, 2015        Specialty Coffee Association
#
#                          certification_address  \
# 0     309fcf77415a3661ae83e027f7e5f05dad786e44
# 1     309fcf77415a3661ae83e027f7e5f05dad786e44
# 2     36d0d00a3724338ba7937c52a378d085f2172daa
# 3     309fcf77415a3661ae83e027f7e5f05dad786e44
# 4     309fcf77415a3661ae83e027f7e5f05dad786e44
# ...                                        ...
# 1334  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1335  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1336  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1337  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1338  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
#
#                          certification_contact unit_of_measurement  \
# 0     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 2     0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 3     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 4     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# ...                                        ...                 ...
# 1334  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1335  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1336  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1337  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1338  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
#
#       altitude_low_meters  altitude_high_meters  altitude_mean_meters
# 0                  1950.0                2200.0                2075.0
# 1                  1950.0                2200.0                2075.0
# 2                  1600.0                1800.0                1700.0
# 3                  1800.0                2200.0                2000.0
# 4                  1950.0                2200.0                2075.0
# ...                   ...                   ...                   ...
# 1334                  NaN                   NaN                   NaN
# 1335                 40.0                  40.0                  40.0
# 1336                795.0                 795.0                 795.0
# 1337                  NaN                   NaN                   NaN
# 1338                  NaN                   NaN                   NaN
#
# [1339 rows x 43 columns]

# %%
pd.read_csv('data/teste1.csv',index_col = 0)
# Out:
#       total_cup_points  species                     owner country_of_origin  \
# 0                90.58  Arabica                 metad plc          Ethiopia
# 1                89.92  Arabica                 metad plc          Ethiopia
# 2                89.75  Arabica  grounds for health admin         Guatemala
# 3                89.00  Arabica       yidnekachew dabessa          Ethiopia
# 4                88.83  Arabica                 metad plc          Ethiopia
# ...                ...      ...                       ...               ...
# 1334             78.75  Robusta               luis robles           Ecuador
# 1335             78.08  Robusta               luis robles           Ecuador
# 1336             77.17  Robusta               james moore     United States
# 1337             75.08  Robusta             cafe politico             India
# 1338             73.75  Robusta             cafe politico           Vietnam
#
#                                      farm_name lot_number            mill  \
# 0                                    metad plc        NaN       metad plc
# 1                                    metad plc        NaN       metad plc
# 2     san marcos barrancas "san cristobal cuch        NaN             NaN
# 3        yidnekachew dabessa coffee plantation        NaN         wolensu
# 4                                    metad plc        NaN       metad plc
# ...                                        ...        ...             ...
# 1334                                 robustasa   Lavado 1     our own lab
# 1335                                 robustasa   Lavado 3  own laboratory
# 1336                           fazenda cazengo        NaN    cafe cazengo
# 1337                                       NaN        NaN             NaN
# 1338                                       NaN        NaN             NaN
#
#              ico_number                                company       altitude  \
# 0             2014/2015      metad agricultural developmet plc      1950-2200
# 1             2014/2015      metad agricultural developmet plc      1950-2200
# 2                   NaN                                    NaN  1600 - 1800 m
# 3                   NaN  yidnekachew debessa coffee plantation      1800-2200
# 4             2014/2015      metad agricultural developmet plc      1950-2200
# ...                 ...                                    ...            ...
# 1334                NaN                              robustasa            NaN
# 1335                NaN                              robustasa             40
# 1336                NaN                global opportunity fund     795 meters
# 1337  14-1118-2014-0087                          cafe politico            NaN
# 1338                NaN                          cafe politico            NaN
#
#                              region                               producer  \
# 0                      guji-hambela                              METAD PLC
# 1                      guji-hambela                              METAD PLC
# 2                               NaN                                    NaN
# 3                            oromia  Yidnekachew Dabessa Coffee Plantation
# 4                      guji-hambela                              METAD PLC
# ...                             ...                                    ...
# 1334               san juan, playas          Café Robusta del Ecuador S.A.
# 1335               san juan, playas          Café Robusta del Ecuador S.A.
# 1336  kwanza norte province, angola                           Cafe Cazengo
# 1337                            NaN                                    NaN
# 1338                            NaN                                    NaN
#
#       number_of_bags bag_weight                  in_country_partner  \
# 0                300      60 kg  METAD Agricultural Development plc
# 1                300      60 kg  METAD Agricultural Development plc
# 2                  5          1        Specialty Coffee Association
# 3                320      60 kg  METAD Agricultural Development plc
# 4                300      60 kg  METAD Agricultural Development plc
# ...              ...        ...                                 ...
# 1334               1       2 kg        Specialty Coffee Association
# 1335               1       2 kg        Specialty Coffee Association
# 1336               1       1 kg        Specialty Coffee Association
# 1337               1      5 lbs        Specialty Coffee Association
# 1338               1      5 lbs        Specialty Coffee Association
#
#      harvest_year         grading_date                   owner_1  variety  \
# 0            2014      April 4th, 2015                 metad plc      NaN
# 1            2014      April 4th, 2015                 metad plc    Other
# 2             NaN       May 31st, 2010  Grounds for Health Admin  Bourbon
# 3            2014     March 26th, 2015       Yidnekachew Dabessa      NaN
# 4            2014      April 4th, 2015                 metad plc    Other
# ...           ...                  ...                       ...      ...
# 1334         2016   January 19th, 2016               Luis Robles      NaN
# 1335         2016   January 19th, 2016               Luis Robles      NaN
# 1336         2014  December 23rd, 2014               James Moore      NaN
# 1337         2013    August 25th, 2014             Cafe Politico      NaN
# 1338         2013    August 25th, 2014             Cafe Politico      NaN
#
#      processing_method  aroma  flavor  aftertaste  acidity  body  balance  \
# 0         Washed / Wet   8.67    8.83        8.67     8.75  8.50     8.42
# 1         Washed / Wet   8.75    8.67        8.50     8.58  8.42     8.42
# 2                  NaN   8.42    8.50        8.42     8.42  8.33     8.42
# 3        Natural / Dry   8.17    8.58        8.42     8.42  8.50     8.25
# 4         Washed / Wet   8.25    8.50        8.25     8.50  8.42     8.33
# ...                ...    ...     ...         ...      ...   ...      ...
# 1334               NaN   7.75    7.58        7.33     7.58  5.08     7.83
# 1335               NaN   7.50    7.67        7.75     7.75  5.17     5.25
# 1336     Natural / Dry   7.33    7.33        7.17     7.42  7.50     7.17
# 1337     Natural / Dry   7.42    6.83        6.75     7.17  7.25     7.00
# 1338     Natural / Dry   6.75    6.67        6.50     6.83  6.92     6.83
#
#       uniformity  clean_cup  sweetness  cupper_points  moisture  \
# 0          10.00      10.00      10.00           8.75      0.12
# 1          10.00      10.00      10.00           8.58      0.12
# 2          10.00      10.00      10.00           9.25      0.00
# 3          10.00      10.00      10.00           8.67      0.11
# 4          10.00      10.00      10.00           8.58      0.12
# ...          ...        ...        ...            ...       ...
# 1334       10.00      10.00       7.75           7.83      0.00
# 1335       10.00      10.00       8.42           8.58      0.00
# 1336        9.33       9.33       7.42           7.17      0.00
# 1337        9.33       9.33       7.08           6.92      0.10
# 1338        9.33       9.33       6.67           7.92      0.12
#
#       category_one_defects  quakers       color  category_two_defects  \
# 0                        0      0.0       Green                     0
# 1                        0      0.0       Green                     1
# 2                        0      0.0         NaN                     0
# 3                        0      0.0       Green                     2
# 4                        0      0.0       Green                     2
# ...                    ...      ...         ...                   ...
# 1334                     0      0.0  Blue-Green                     1
# 1335                     0      0.0  Blue-Green                     0
# 1336                     0      0.0         NaN                     6
# 1337                    20      0.0       Green                     1
# 1338                    63      0.0        None                     9
#
#                expiration                  certification_body  \
# 0         April 3rd, 2016  METAD Agricultural Development plc
# 1         April 3rd, 2016  METAD Agricultural Development plc
# 2          May 31st, 2011        Specialty Coffee Association
# 3        March 25th, 2016  METAD Agricultural Development plc
# 4         April 3rd, 2016  METAD Agricultural Development plc
# ...                   ...                                 ...
# 1334   January 18th, 2017        Specialty Coffee Association
# 1335   January 18th, 2017        Specialty Coffee Association
# 1336  December 23rd, 2015        Specialty Coffee Association
# 1337    August 25th, 2015        Specialty Coffee Association
# 1338    August 25th, 2015        Specialty Coffee Association
#
#                          certification_address  \
# 0     309fcf77415a3661ae83e027f7e5f05dad786e44
# 1     309fcf77415a3661ae83e027f7e5f05dad786e44
# 2     36d0d00a3724338ba7937c52a378d085f2172daa
# 3     309fcf77415a3661ae83e027f7e5f05dad786e44
# 4     309fcf77415a3661ae83e027f7e5f05dad786e44
# ...                                        ...
# 1334  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1335  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1336  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1337  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1338  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
#
#                          certification_contact unit_of_measurement  \
# 0     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 2     0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 3     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 4     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# ...                                        ...                 ...
# 1334  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1335  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1336  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1337  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1338  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
#
#       altitude_low_meters  altitude_high_meters  altitude_mean_meters
# 0                  1950.0                2200.0                2075.0
# 1                  1950.0                2200.0                2075.0
# 2                  1600.0                1800.0                1700.0
# 3                  1800.0                2200.0                2000.0
# 4                  1950.0                2200.0                2075.0
# ...                   ...                   ...                   ...
# 1334                  NaN                   NaN                   NaN
# 1335                 40.0                  40.0                  40.0
# 1336                795.0                 795.0                 795.0
# 1337                  NaN                   NaN                   NaN
# 1338                  NaN                   NaN                   NaN
#
# [1339 rows x 43 columns]

# %%
df.to_csv('data/exported_file_v1.csv', index=False)

# %%
pd.read_csv('data/exported_file_v1.csv')
# Out:
#       total_cup_points  species                     owner country_of_origin  \
# 0                90.58  Arabica                 metad plc          Ethiopia
# 1                89.92  Arabica                 metad plc          Ethiopia
# 2                89.75  Arabica  grounds for health admin         Guatemala
# 3                89.00  Arabica       yidnekachew dabessa          Ethiopia
# 4                88.83  Arabica                 metad plc          Ethiopia
# ...                ...      ...                       ...               ...
# 1334             78.75  Robusta               luis robles           Ecuador
# 1335             78.08  Robusta               luis robles           Ecuador
# 1336             77.17  Robusta               james moore     United States
# 1337             75.08  Robusta             cafe politico             India
# 1338             73.75  Robusta             cafe politico           Vietnam
#
#                                      farm_name lot_number            mill  \
# 0                                    metad plc        NaN       metad plc
# 1                                    metad plc        NaN       metad plc
# 2     san marcos barrancas "san cristobal cuch        NaN             NaN
# 3        yidnekachew dabessa coffee plantation        NaN         wolensu
# 4                                    metad plc        NaN       metad plc
# ...                                        ...        ...             ...
# 1334                                 robustasa   Lavado 1     our own lab
# 1335                                 robustasa   Lavado 3  own laboratory
# 1336                           fazenda cazengo        NaN    cafe cazengo
# 1337                                       NaN        NaN             NaN
# 1338                                       NaN        NaN             NaN
#
#              ico_number                                company       altitude  \
# 0             2014/2015      metad agricultural developmet plc      1950-2200
# 1             2014/2015      metad agricultural developmet plc      1950-2200
# 2                   NaN                                    NaN  1600 - 1800 m
# 3                   NaN  yidnekachew debessa coffee plantation      1800-2200
# 4             2014/2015      metad agricultural developmet plc      1950-2200
# ...                 ...                                    ...            ...
# 1334                NaN                              robustasa            NaN
# 1335                NaN                              robustasa             40
# 1336                NaN                global opportunity fund     795 meters
# 1337  14-1118-2014-0087                          cafe politico            NaN
# 1338                NaN                          cafe politico            NaN
#
#                              region                               producer  \
# 0                      guji-hambela                              METAD PLC
# 1                      guji-hambela                              METAD PLC
# 2                               NaN                                    NaN
# 3                            oromia  Yidnekachew Dabessa Coffee Plantation
# 4                      guji-hambela                              METAD PLC
# ...                             ...                                    ...
# 1334               san juan, playas          Café Robusta del Ecuador S.A.
# 1335               san juan, playas          Café Robusta del Ecuador S.A.
# 1336  kwanza norte province, angola                           Cafe Cazengo
# 1337                            NaN                                    NaN
# 1338                            NaN                                    NaN
#
#       number_of_bags bag_weight                  in_country_partner  \
# 0                300      60 kg  METAD Agricultural Development plc
# 1                300      60 kg  METAD Agricultural Development plc
# 2                  5          1        Specialty Coffee Association
# 3                320      60 kg  METAD Agricultural Development plc
# 4                300      60 kg  METAD Agricultural Development plc
# ...              ...        ...                                 ...
# 1334               1       2 kg        Specialty Coffee Association
# 1335               1       2 kg        Specialty Coffee Association
# 1336               1       1 kg        Specialty Coffee Association
# 1337               1      5 lbs        Specialty Coffee Association
# 1338               1      5 lbs        Specialty Coffee Association
#
#      harvest_year         grading_date                   owner_1  variety  \
# 0            2014      April 4th, 2015                 metad plc      NaN
# 1            2014      April 4th, 2015                 metad plc    Other
# 2             NaN       May 31st, 2010  Grounds for Health Admin  Bourbon
# 3            2014     March 26th, 2015       Yidnekachew Dabessa      NaN
# 4            2014      April 4th, 2015                 metad plc    Other
# ...           ...                  ...                       ...      ...
# 1334         2016   January 19th, 2016               Luis Robles      NaN
# 1335         2016   January 19th, 2016               Luis Robles      NaN
# 1336         2014  December 23rd, 2014               James Moore      NaN
# 1337         2013    August 25th, 2014             Cafe Politico      NaN
# 1338         2013    August 25th, 2014             Cafe Politico      NaN
#
#      processing_method  aroma  flavor  aftertaste  acidity  body  balance  \
# 0         Washed / Wet   8.67    8.83        8.67     8.75  8.50     8.42
# 1         Washed / Wet   8.75    8.67        8.50     8.58  8.42     8.42
# 2                  NaN   8.42    8.50        8.42     8.42  8.33     8.42
# 3        Natural / Dry   8.17    8.58        8.42     8.42  8.50     8.25
# 4         Washed / Wet   8.25    8.50        8.25     8.50  8.42     8.33
# ...                ...    ...     ...         ...      ...   ...      ...
# 1334               NaN   7.75    7.58        7.33     7.58  5.08     7.83
# 1335               NaN   7.50    7.67        7.75     7.75  5.17     5.25
# 1336     Natural / Dry   7.33    7.33        7.17     7.42  7.50     7.17
# 1337     Natural / Dry   7.42    6.83        6.75     7.17  7.25     7.00
# 1338     Natural / Dry   6.75    6.67        6.50     6.83  6.92     6.83
#
#       uniformity  clean_cup  sweetness  cupper_points  moisture  \
# 0          10.00      10.00      10.00           8.75      0.12
# 1          10.00      10.00      10.00           8.58      0.12
# 2          10.00      10.00      10.00           9.25      0.00
# 3          10.00      10.00      10.00           8.67      0.11
# 4          10.00      10.00      10.00           8.58      0.12
# ...          ...        ...        ...            ...       ...
# 1334       10.00      10.00       7.75           7.83      0.00
# 1335       10.00      10.00       8.42           8.58      0.00
# 1336        9.33       9.33       7.42           7.17      0.00
# 1337        9.33       9.33       7.08           6.92      0.10
# 1338        9.33       9.33       6.67           7.92      0.12
#
#       category_one_defects  quakers       color  category_two_defects  \
# 0                        0      0.0       Green                     0
# 1                        0      0.0       Green                     1
# 2                        0      0.0         NaN                     0
# 3                        0      0.0       Green                     2
# 4                        0      0.0       Green                     2
# ...                    ...      ...         ...                   ...
# 1334                     0      0.0  Blue-Green                     1
# 1335                     0      0.0  Blue-Green                     0
# 1336                     0      0.0         NaN                     6
# 1337                    20      0.0       Green                     1
# 1338                    63      0.0        None                     9
#
#                expiration                  certification_body  \
# 0         April 3rd, 2016  METAD Agricultural Development plc
# 1         April 3rd, 2016  METAD Agricultural Development plc
# 2          May 31st, 2011        Specialty Coffee Association
# 3        March 25th, 2016  METAD Agricultural Development plc
# 4         April 3rd, 2016  METAD Agricultural Development plc
# ...                   ...                                 ...
# 1334   January 18th, 2017        Specialty Coffee Association
# 1335   January 18th, 2017        Specialty Coffee Association
# 1336  December 23rd, 2015        Specialty Coffee Association
# 1337    August 25th, 2015        Specialty Coffee Association
# 1338    August 25th, 2015        Specialty Coffee Association
#
#                          certification_address  \
# 0     309fcf77415a3661ae83e027f7e5f05dad786e44
# 1     309fcf77415a3661ae83e027f7e5f05dad786e44
# 2     36d0d00a3724338ba7937c52a378d085f2172daa
# 3     309fcf77415a3661ae83e027f7e5f05dad786e44
# 4     309fcf77415a3661ae83e027f7e5f05dad786e44
# ...                                        ...
# 1334  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1335  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1336  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1337  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1338  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
#
#                          certification_contact unit_of_measurement  \
# 0     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 2     0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 3     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 4     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# ...                                        ...                 ...
# 1334  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1335  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1336  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1337  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1338  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
#
#       altitude_low_meters  altitude_high_meters  altitude_mean_meters
# 0                  1950.0                2200.0                2075.0
# 1                  1950.0                2200.0                2075.0
# 2                  1600.0                1800.0                1700.0
# 3                  1800.0                2200.0                2000.0
# 4                  1950.0                2200.0                2075.0
# ...                   ...                   ...                   ...
# 1334                  NaN                   NaN                   NaN
# 1335                 40.0                  40.0                  40.0
# 1336                795.0                 795.0                 795.0
# 1337                  NaN                   NaN                   NaN
# 1338                  NaN                   NaN                   NaN
#
# [1339 rows x 43 columns]

# %%
#pd.read_csv('data/exported_file_v2.csv', index_col=0)
# Out:
#      unplanted3    planted3  unplanted7    planted7  unplanted10   planted10  \
# 0      0.000000   78.636959   84.820995   52.068175    84.783652   85.310734
# 1      0.000000   14.616304   14.015557    0.000000    40.375704   28.928829
# 2     80.511993   89.752898   87.460473   89.376096    94.163425   87.193210
# 3     75.900402   87.403649   80.646947   93.727934    93.886463   94.274587
# 4     15.042991   69.794541   49.785408   82.442805    17.340252   78.333261
# ..          ...         ...         ...         ...          ...         ...
# 215   65.309446   87.153652   74.054054   86.700913    63.328034   91.534091
# 216    0.000000   48.520710   38.206278    0.000000    34.740545   71.739130
# 217   28.395062   83.783784   66.559486  100.000000   100.000000  100.000000
# 218   59.640103  100.000000   44.281525  100.000000   100.000000  100.000000
# 219   10.194175  100.000000  100.000000  100.000000   100.000000  100.000000
#
#     wether  parameter        date
# 0      wet  turbidity  2018-02-09
# 1      wet  turbidity  2018-02-15
# 2      wet  turbidity  2018-02-22
# 3      wet  turbidity  2018-03-01
# 4      wet  turbidity  2018-03-08
# ..     ...        ...         ...
# 215    wet         pt  2018-10-05
# 216    wet         pt  2018-10-11
# 217    wet         pt  2018-10-18
# 218    wet         pt  2018-10-25
# 219    wet         pt  2018-10-31
#
# [220 rows x 9 columns]

# %% [markdown]
# **NOTE**: If you do not specify the argument `index=False`, the output in the csv file will create an unnamed index column with the *dataframe indexes*.

# %%
df.to_csv('data/exported_file.csv', index=False)

# %% [markdown]
# ## Export to csv using a specific separator

# %% [markdown]
# ### Semicolon

# %%
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
df.to_csv('data/exported_file_semicolon_excel.xlsx', index=False, sep=';')

# %%
pd.read_csv('data/exported_file_semicolon_excel.xlsx',sep=';')
# Out:
#       total_cup_points  species                     owner country_of_origin  \
# 0                90.58  Arabica                 metad plc          Ethiopia
# 1                89.92  Arabica                 metad plc          Ethiopia
# 2                89.75  Arabica  grounds for health admin         Guatemala
# 3                89.00  Arabica       yidnekachew dabessa          Ethiopia
# 4                88.83  Arabica                 metad plc          Ethiopia
# ...                ...      ...                       ...               ...
# 1334             78.75  Robusta               luis robles           Ecuador
# 1335             78.08  Robusta               luis robles           Ecuador
# 1336             77.17  Robusta               james moore     United States
# 1337             75.08  Robusta             cafe politico             India
# 1338             73.75  Robusta             cafe politico           Vietnam
#
#                                      farm_name lot_number            mill  \
# 0                                    metad plc        NaN       metad plc
# 1                                    metad plc        NaN       metad plc
# 2     san marcos barrancas "san cristobal cuch        NaN             NaN
# 3        yidnekachew dabessa coffee plantation        NaN         wolensu
# 4                                    metad plc        NaN       metad plc
# ...                                        ...        ...             ...
# 1334                                 robustasa   Lavado 1     our own lab
# 1335                                 robustasa   Lavado 3  own laboratory
# 1336                           fazenda cazengo        NaN    cafe cazengo
# 1337                                       NaN        NaN             NaN
# 1338                                       NaN        NaN             NaN
#
#              ico_number                                company       altitude  \
# 0             2014/2015      metad agricultural developmet plc      1950-2200
# 1             2014/2015      metad agricultural developmet plc      1950-2200
# 2                   NaN                                    NaN  1600 - 1800 m
# 3                   NaN  yidnekachew debessa coffee plantation      1800-2200
# 4             2014/2015      metad agricultural developmet plc      1950-2200
# ...                 ...                                    ...            ...
# 1334                NaN                              robustasa            NaN
# 1335                NaN                              robustasa             40
# 1336                NaN                global opportunity fund     795 meters
# 1337  14-1118-2014-0087                          cafe politico            NaN
# 1338                NaN                          cafe politico            NaN
#
#                              region                               producer  \
# 0                      guji-hambela                              METAD PLC
# 1                      guji-hambela                              METAD PLC
# 2                               NaN                                    NaN
# 3                            oromia  Yidnekachew Dabessa Coffee Plantation
# 4                      guji-hambela                              METAD PLC
# ...                             ...                                    ...
# 1334               san juan, playas          Café Robusta del Ecuador S.A.
# 1335               san juan, playas          Café Robusta del Ecuador S.A.
# 1336  kwanza norte province, angola                           Cafe Cazengo
# 1337                            NaN                                    NaN
# 1338                            NaN                                    NaN
#
#       number_of_bags bag_weight                  in_country_partner  \
# 0                300      60 kg  METAD Agricultural Development plc
# 1                300      60 kg  METAD Agricultural Development plc
# 2                  5          1        Specialty Coffee Association
# 3                320      60 kg  METAD Agricultural Development plc
# 4                300      60 kg  METAD Agricultural Development plc
# ...              ...        ...                                 ...
# 1334               1       2 kg        Specialty Coffee Association
# 1335               1       2 kg        Specialty Coffee Association
# 1336               1       1 kg        Specialty Coffee Association
# 1337               1      5 lbs        Specialty Coffee Association
# 1338               1      5 lbs        Specialty Coffee Association
#
#      harvest_year         grading_date                   owner_1  variety  \
# 0            2014      April 4th, 2015                 metad plc      NaN
# 1            2014      April 4th, 2015                 metad plc    Other
# 2             NaN       May 31st, 2010  Grounds for Health Admin  Bourbon
# 3            2014     March 26th, 2015       Yidnekachew Dabessa      NaN
# 4            2014      April 4th, 2015                 metad plc    Other
# ...           ...                  ...                       ...      ...
# 1334         2016   January 19th, 2016               Luis Robles      NaN
# 1335         2016   January 19th, 2016               Luis Robles      NaN
# 1336         2014  December 23rd, 2014               James Moore      NaN
# 1337         2013    August 25th, 2014             Cafe Politico      NaN
# 1338         2013    August 25th, 2014             Cafe Politico      NaN
#
#      processing_method  aroma  flavor  aftertaste  acidity  body  balance  \
# 0         Washed / Wet   8.67    8.83        8.67     8.75  8.50     8.42
# 1         Washed / Wet   8.75    8.67        8.50     8.58  8.42     8.42
# 2                  NaN   8.42    8.50        8.42     8.42  8.33     8.42
# 3        Natural / Dry   8.17    8.58        8.42     8.42  8.50     8.25
# 4         Washed / Wet   8.25    8.50        8.25     8.50  8.42     8.33
# ...                ...    ...     ...         ...      ...   ...      ...
# 1334               NaN   7.75    7.58        7.33     7.58  5.08     7.83
# 1335               NaN   7.50    7.67        7.75     7.75  5.17     5.25
# 1336     Natural / Dry   7.33    7.33        7.17     7.42  7.50     7.17
# 1337     Natural / Dry   7.42    6.83        6.75     7.17  7.25     7.00
# 1338     Natural / Dry   6.75    6.67        6.50     6.83  6.92     6.83
#
#       uniformity  clean_cup  sweetness  cupper_points  moisture  \
# 0          10.00      10.00      10.00           8.75      0.12
# 1          10.00      10.00      10.00           8.58      0.12
# 2          10.00      10.00      10.00           9.25      0.00
# 3          10.00      10.00      10.00           8.67      0.11
# 4          10.00      10.00      10.00           8.58      0.12
# ...          ...        ...        ...            ...       ...
# 1334       10.00      10.00       7.75           7.83      0.00
# 1335       10.00      10.00       8.42           8.58      0.00
# 1336        9.33       9.33       7.42           7.17      0.00
# 1337        9.33       9.33       7.08           6.92      0.10
# 1338        9.33       9.33       6.67           7.92      0.12
#
#       category_one_defects  quakers       color  category_two_defects  \
# 0                        0      0.0       Green                     0
# 1                        0      0.0       Green                     1
# 2                        0      0.0         NaN                     0
# 3                        0      0.0       Green                     2
# 4                        0      0.0       Green                     2
# ...                    ...      ...         ...                   ...
# 1334                     0      0.0  Blue-Green                     1
# 1335                     0      0.0  Blue-Green                     0
# 1336                     0      0.0         NaN                     6
# 1337                    20      0.0       Green                     1
# 1338                    63      0.0        None                     9
#
#                expiration                  certification_body  \
# 0         April 3rd, 2016  METAD Agricultural Development plc
# 1         April 3rd, 2016  METAD Agricultural Development plc
# 2          May 31st, 2011        Specialty Coffee Association
# 3        March 25th, 2016  METAD Agricultural Development plc
# 4         April 3rd, 2016  METAD Agricultural Development plc
# ...                   ...                                 ...
# 1334   January 18th, 2017        Specialty Coffee Association
# 1335   January 18th, 2017        Specialty Coffee Association
# 1336  December 23rd, 2015        Specialty Coffee Association
# 1337    August 25th, 2015        Specialty Coffee Association
# 1338    August 25th, 2015        Specialty Coffee Association
#
#                          certification_address  \
# 0     309fcf77415a3661ae83e027f7e5f05dad786e44
# 1     309fcf77415a3661ae83e027f7e5f05dad786e44
# 2     36d0d00a3724338ba7937c52a378d085f2172daa
# 3     309fcf77415a3661ae83e027f7e5f05dad786e44
# 4     309fcf77415a3661ae83e027f7e5f05dad786e44
# ...                                        ...
# 1334  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1335  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1336  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1337  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1338  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
#
#                          certification_contact unit_of_measurement  \
# 0     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 2     0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 3     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 4     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# ...                                        ...                 ...
# 1334  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1335  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1336  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1337  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1338  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
#
#       altitude_low_meters  altitude_high_meters  altitude_mean_meters
# 0                  1950.0                2200.0                2075.0
# 1                  1950.0                2200.0                2075.0
# 2                  1600.0                1800.0                1700.0
# 3                  1800.0                2200.0                2000.0
# 4                  1950.0                2200.0                2075.0
# ...                   ...                   ...                   ...
# 1334                  NaN                   NaN                   NaN
# 1335                 40.0                  40.0                  40.0
# 1336                795.0                 795.0                 795.0
# 1337                  NaN                   NaN                   NaN
# 1338                  NaN                   NaN                   NaN
#
# [1339 rows x 43 columns]

# %% [markdown]
# ### Pipe

# %%
df.to_csv('data/exported_file_pipe.csv', index=False, sep='|')

# %% [markdown]
# ### plust or minus

# %%
df.to_csv('data/exported_file_plusminus.csv', index=False, sep='±')

# %% [markdown]
# ## Export TO EXCEL

# %%
df.to_excel('data/aldrey_treated_newversion2.xlsx', sheet_name='treated')

# %%
pd.read_excel('data/aldrey_treated_newversion2.xlsx')
# Out:
#       Unnamed: 0  total_cup_points  species                     owner  \
# 0              0             90.58  Arabica                 metad plc
# 1              1             89.92  Arabica                 metad plc
# 2              2             89.75  Arabica  grounds for health admin
# 3              3             89.00  Arabica       yidnekachew dabessa
# 4              4             88.83  Arabica                 metad plc
# ...          ...               ...      ...                       ...
# 1334        1334             78.75  Robusta               luis robles
# 1335        1335             78.08  Robusta               luis robles
# 1336        1336             77.17  Robusta               james moore
# 1337        1337             75.08  Robusta             cafe politico
# 1338        1338             73.75  Robusta             cafe politico
#
#      country_of_origin                                 farm_name lot_number  \
# 0             Ethiopia                                 metad plc        NaN
# 1             Ethiopia                                 metad plc        NaN
# 2            Guatemala  san marcos barrancas "san cristobal cuch        NaN
# 3             Ethiopia     yidnekachew dabessa coffee plantation        NaN
# 4             Ethiopia                                 metad plc        NaN
# ...                ...                                       ...        ...
# 1334           Ecuador                                 robustasa   Lavado 1
# 1335           Ecuador                                 robustasa   Lavado 3
# 1336     United States                           fazenda cazengo        NaN
# 1337             India                                       NaN        NaN
# 1338           Vietnam                                       NaN        NaN
#
#                 mill         ico_number  \
# 0          metad plc          2014/2015
# 1          metad plc          2014/2015
# 2                NaN                NaN
# 3            wolensu                NaN
# 4          metad plc          2014/2015
# ...              ...                ...
# 1334     our own lab                NaN
# 1335  own laboratory                NaN
# 1336    cafe cazengo                NaN
# 1337             NaN  14-1118-2014-0087
# 1338             NaN                NaN
#
#                                     company       altitude  \
# 0         metad agricultural developmet plc      1950-2200
# 1         metad agricultural developmet plc      1950-2200
# 2                                       NaN  1600 - 1800 m
# 3     yidnekachew debessa coffee plantation      1800-2200
# 4         metad agricultural developmet plc      1950-2200
# ...                                     ...            ...
# 1334                              robustasa            NaN
# 1335                              robustasa             40
# 1336                global opportunity fund     795 meters
# 1337                          cafe politico            NaN
# 1338                          cafe politico            NaN
#
#                              region                               producer  \
# 0                      guji-hambela                              METAD PLC
# 1                      guji-hambela                              METAD PLC
# 2                               NaN                                    NaN
# 3                            oromia  Yidnekachew Dabessa Coffee Plantation
# 4                      guji-hambela                              METAD PLC
# ...                             ...                                    ...
# 1334               san juan, playas          Café Robusta del Ecuador S.A.
# 1335               san juan, playas          Café Robusta del Ecuador S.A.
# 1336  kwanza norte province, angola                           Cafe Cazengo
# 1337                            NaN                                    NaN
# 1338                            NaN                                    NaN
#
#       number_of_bags bag_weight                  in_country_partner  \
# 0                300      60 kg  METAD Agricultural Development plc
# 1                300      60 kg  METAD Agricultural Development plc
# 2                  5          1        Specialty Coffee Association
# 3                320      60 kg  METAD Agricultural Development plc
# 4                300      60 kg  METAD Agricultural Development plc
# ...              ...        ...                                 ...
# 1334               1       2 kg        Specialty Coffee Association
# 1335               1       2 kg        Specialty Coffee Association
# 1336               1       1 kg        Specialty Coffee Association
# 1337               1      5 lbs        Specialty Coffee Association
# 1338               1      5 lbs        Specialty Coffee Association
#
#      harvest_year         grading_date                   owner_1  variety  \
# 0            2014      April 4th, 2015                 metad plc      NaN
# 1            2014      April 4th, 2015                 metad plc    Other
# 2             NaN       May 31st, 2010  Grounds for Health Admin  Bourbon
# 3            2014     March 26th, 2015       Yidnekachew Dabessa      NaN
# 4            2014      April 4th, 2015                 metad plc    Other
# ...           ...                  ...                       ...      ...
# 1334         2016   January 19th, 2016               Luis Robles      NaN
# 1335         2016   January 19th, 2016               Luis Robles      NaN
# 1336         2014  December 23rd, 2014               James Moore      NaN
# 1337         2013    August 25th, 2014             Cafe Politico      NaN
# 1338         2013    August 25th, 2014             Cafe Politico      NaN
#
#      processing_method  aroma  flavor  aftertaste  acidity  body  balance  \
# 0         Washed / Wet   8.67    8.83        8.67     8.75  8.50     8.42
# 1         Washed / Wet   8.75    8.67        8.50     8.58  8.42     8.42
# 2                  NaN   8.42    8.50        8.42     8.42  8.33     8.42
# 3        Natural / Dry   8.17    8.58        8.42     8.42  8.50     8.25
# 4         Washed / Wet   8.25    8.50        8.25     8.50  8.42     8.33
# ...                ...    ...     ...         ...      ...   ...      ...
# 1334               NaN   7.75    7.58        7.33     7.58  5.08     7.83
# 1335               NaN   7.50    7.67        7.75     7.75  5.17     5.25
# 1336     Natural / Dry   7.33    7.33        7.17     7.42  7.50     7.17
# 1337     Natural / Dry   7.42    6.83        6.75     7.17  7.25     7.00
# 1338     Natural / Dry   6.75    6.67        6.50     6.83  6.92     6.83
#
#       uniformity  clean_cup  sweetness  cupper_points  moisture  \
# 0          10.00      10.00      10.00           8.75      0.12
# 1          10.00      10.00      10.00           8.58      0.12
# 2          10.00      10.00      10.00           9.25      0.00
# 3          10.00      10.00      10.00           8.67      0.11
# 4          10.00      10.00      10.00           8.58      0.12
# ...          ...        ...        ...            ...       ...
# 1334       10.00      10.00       7.75           7.83      0.00
# 1335       10.00      10.00       8.42           8.58      0.00
# 1336        9.33       9.33       7.42           7.17      0.00
# 1337        9.33       9.33       7.08           6.92      0.10
# 1338        9.33       9.33       6.67           7.92      0.12
#
#       category_one_defects  quakers       color  category_two_defects  \
# 0                        0      0.0       Green                     0
# 1                        0      0.0       Green                     1
# 2                        0      0.0         NaN                     0
# 3                        0      0.0       Green                     2
# 4                        0      0.0       Green                     2
# ...                    ...      ...         ...                   ...
# 1334                     0      0.0  Blue-Green                     1
# 1335                     0      0.0  Blue-Green                     0
# 1336                     0      0.0         NaN                     6
# 1337                    20      0.0       Green                     1
# 1338                    63      0.0        None                     9
#
#                expiration                  certification_body  \
# 0         April 3rd, 2016  METAD Agricultural Development plc
# 1         April 3rd, 2016  METAD Agricultural Development plc
# 2          May 31st, 2011        Specialty Coffee Association
# 3        March 25th, 2016  METAD Agricultural Development plc
# 4         April 3rd, 2016  METAD Agricultural Development plc
# ...                   ...                                 ...
# 1334   January 18th, 2017        Specialty Coffee Association
# 1335   January 18th, 2017        Specialty Coffee Association
# 1336  December 23rd, 2015        Specialty Coffee Association
# 1337    August 25th, 2015        Specialty Coffee Association
# 1338    August 25th, 2015        Specialty Coffee Association
#
#                          certification_address  \
# 0     309fcf77415a3661ae83e027f7e5f05dad786e44
# 1     309fcf77415a3661ae83e027f7e5f05dad786e44
# 2     36d0d00a3724338ba7937c52a378d085f2172daa
# 3     309fcf77415a3661ae83e027f7e5f05dad786e44
# 4     309fcf77415a3661ae83e027f7e5f05dad786e44
# ...                                        ...
# 1334  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1335  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1336  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1337  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1338  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
#
#                          certification_contact unit_of_measurement  \
# 0     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 2     0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 3     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 4     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# ...                                        ...                 ...
# 1334  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1335  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1336  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1337  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1338  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
#
#       altitude_low_meters  altitude_high_meters  altitude_mean_meters
# 0                  1950.0                2200.0                2075.0
# 1                  1950.0                2200.0                2075.0
# 2                  1600.0                1800.0                1700.0
# 3                  1800.0                2200.0                2000.0
# 4                  1950.0                2200.0                2075.0
# ...                   ...                   ...                   ...
# 1334                  NaN                   NaN                   NaN
# 1335                 40.0                  40.0                  40.0
# 1336                795.0                 795.0                 795.0
# 1337                  NaN                   NaN                   NaN
# 1338                  NaN                   NaN                   NaN
#
# [1339 rows x 44 columns]

# %% [markdown]
# ## Cool Application: Google Sheets

# %% [markdown]
# - get the shareable link and replace the last piece of the url
#     - replace `/edit?usp=sharing` by `/export?format=csv`
#
# (https://stackoverflow.com/questions/19611729/getting-google-spreadsheet-csv-into-a-pandas-dataframe)

# %%
def read_from_gsheets(spreadsheet):
    """
    Transform url into csv 
    """
    working_spreadsheet = spreadsheet.replace('/edit?usp=sharing','/export?format=csv')
    
    return pd.read_csv(working_spreadsheet)

# %%
read_from_gsheets('https://docs.google.com/spreadsheets/d/1GFJqglHnAgnZ0kfBOmgkN8cFq0q2u1LtQNbKvrkRCJ0/edit?usp=sharing')
# Out:
#             Timestamp Qual é a sua altura?
# 0  8/18/2021 11:22:40                 1.62
# 1  8/18/2021 11:22:43                  1.6
# 2  8/18/2021 11:22:47                 1.55
# 3  8/18/2021 11:22:54                177cm
# 4  8/18/2021 11:22:56                  154

# %% [markdown]
# -------

# %% [markdown]
# # Import and export JSON file

# %% [markdown]
# What is a JSON file?

# %% [markdown]
# JSON 1:
# ```json
# { "name":"John", "age":30, "car":null }
# ```
#
# JSON 2:
# ```json
# {"students":[
#    {"name":"Andre", "age":23, "state":"SP"},
#    {"name":"Rodrigo", "age":28, "state":"SP"},
#    {"name":"Raiana", "age":27, "state":"DF"},
#    {"name":"Tieko", "age":28, "state":"BA"}
# ]}
# ```

# %%
data = pd.read_json('data/vehicles.json')

# %%
data.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0          4  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1          6  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2          4  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3          6  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4          6  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# For a JSON file, you can have different `orient` options.
#
# `'split'`: Dictionary containing indexes, columns, and data.
#
# `'index'`: Nested dictionaries containing {index:{column:value}}.
#
# `'columns'`: Nested dictionaries containing {column:{index:value}}
#
# `'values'`: Nested list where each sublist contains the values for a record.
#
# `'table'`: Nested dictionaries containing schema and data (records).

# %%
data.sample(10).to_json('data/vehicles_split.json', orient='split')
data.sample(10).to_json('data/vehicles_index.json', orient='index')
data.sample(10).to_json('data/vehicles_columns.json', orient='columns')
data.sample(10).to_json('data/vehicles_values.json', orient='values')
data.sample(10).to_json('data/vehicles_table.json', orient='table')

# %%
 pd.read_json('data/vehicles_index.json',orient = 'index')
# Out:
#             Make                Model  Year  Engine Displacement  Cylinders  \
# 30670     Saturn            Relay FWD  2007                  3.9          6
# 22959      Mazda                 MX-5  2008                  2.0          4
# 11788       Ford      E150 Club Wagon  2002                  5.4          8
# 5533   Chevrolet             Corvette  2002                  5.7          8
# 3968    Cadillac             Cimarron  1987                  2.8          6
# 30908      Scion                   xA  2005                  1.5          4
# 10177      Dodge             Intrepid  1998                  2.7          6
# 9284       Dodge  Caravan/Ram Van 2WD  1984                  2.6          4
# 33983     Toyota           Tundra 2WD  2014                  5.7          8
# 28105   Plymouth              Turismo  1985                  2.2          4
#
#           Transmission         Drivetrain                Vehicle Class  \
# 30670  Automatic 4-spd  Front-Wheel Drive                Minivan - 2WD
# 22959     Manual 5-spd   Rear-Wheel Drive                  Two Seaters
# 11788  Automatic 4-spd   Rear-Wheel Drive         Vans, Passenger Type
# 5533      Manual 6-spd   Rear-Wheel Drive                  Two Seaters
# 3968   Automatic 3-spd  Front-Wheel Drive                 Compact Cars
# 30908     Manual 5-spd  Front-Wheel Drive              Subcompact Cars
# 10177  Automatic 4-spd  Front-Wheel Drive                   Large Cars
# 9284   Automatic 3-spd      2-Wheel Drive  Special Purpose Vehicle 2WD
# 33983   Automatic (S6)   Rear-Wheel Drive   Standard Pickup Trucks 2WD
# 28105     Manual 5-spd  Front-Wheel Drive              Subcompact Cars
#
#              Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  \
# 30670  Gasoline or E85          17.347895        16           23
# 22959          Premium          13.733750        22           27
# 11788          Regular          25.354615        12           16
# 5533           Premium          16.480500        17           26
# 3968           Regular          16.480500        18           24
# 30908          Regular          10.987000        27           34
# 10177          Regular          14.982273        18           28
# 9284           Regular          18.311667        17           20
# 33983          Regular          21.974000        13           18
# 28105          Premium          15.695714        18           27
#
#        Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 30670            19               467.736842            1750
# 22959            24               370.291667            1700
# 11788            13               683.615385            2550
# 5533             20               444.350000            2000
# 3968             20               444.350000            1650
# 30908            30               296.233333            1100
# 10177            22               403.954545            1500
# 9284             18               493.722222            1850
# 33983            15               602.000000            2200
# 28105            21               423.190476            1950
